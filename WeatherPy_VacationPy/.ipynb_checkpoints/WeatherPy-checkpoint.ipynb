# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt  

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low = -90, high = 90, size=1500)
lngs = np.random.uniform(low = -180, high = 180, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 0
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

print(f"Beginning Data Retrieval")
print(f"------------------------------")
for city in cities:
        url = (f'https://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}')
#         print(url)
        weather_response = requests.get(url)
        weather_json = weather_response.json()
#         print(weather_json)
        try: 
            Cloudiness.append(weather_json['clouds']["all"])
            Country.append(weather_json['sys']["country"])
            Date.append(weather_json["dt"])
            Humidity.append(weather_json["main"]['humidity'])
            Lat.append(weather_json["coord"]['lat'])
            Lng.append(weather_json["coord"]['lon'])
            Max_Temp.append(weather_json["main"]['temp_max'])
            Wind_Speed.append(weather_json["wind"]['speed'])
            print( "Requesting " , count,"......" ,city)
            count = count + 1
            
        except KeyError:
        
            Cloudiness.append("")
            Country.append("")
            Date.append("")
            Humidity.append("")
            Lat.append("")
            Lng.append("")
            Max_Temp.append("")
            Wind_Speed.append("")
            print("Requesting " , count,"......" ,city, ".....Empty value, request again...")
            count = count + 1
# Out:
# Beginning Data Retrieval
# ------------------------------
# Requesting  0 ...... eureka
# Requesting  1 ...... hilo
# Requesting  2 ...... sentyabrskiy .....Empty value, request again...
# Requesting  3 ...... albany
# Requesting  4 ...... hofn
# Requesting  5 ...... belushya guba .....Empty value, request again...
# Requesting  6 ...... zeya
# Requesting  7 ...... torbay
# Requesting  8 ...... bluff
# Requesting  9 ...... san patricio
# Requesting  10 ...... ust-maya
# Requesting  11 ...... kapaa
# Requesting  12 ...... port alfred
# Requesting  13 ...... atuona
# Requesting  14 ...... bengkulu
# Requesting  15 ...... ushuaia
# Requesting  16 ...... mataura
# Requesting  17 ...... umzimvubu .....Empty value, request again...
# Requesting  18 ...... jamestown
# Requesting  19 ...... vila
# Requesting  20 ...... taolanaro .....Empty value, request again...
# Requesting  21 ...... oriximina
# Requesting  22 ...... thinadhoo
# Requesting  23 ...... busselton
# Requesting  24 ...... rafraf
# Requesting  25 ...... dubbo
# Requesting  26 ...... quatre cocos
# Requesting  27 ...... dingle
# Requesting  28 ...... port blair
# Requesting  29 ...... saint george
# Requesting  30 ...... houma
# Requesting  31 ...... lompoc
# Requesting  32 ...... pringsewu
# Requesting  33 ...... lasa
# Requesting  34 ...... vokhtoga
# Requesting  35 ...... muli
# Requesting  36 ...... punta arenas
# Requesting  37 ...... castro
# Requesting  38 ...... upernavik
# Requesting  39 ...... obo
# Requesting  40 ...... akdepe
# Requesting  41 ...... rikitea
# Requesting  42 ...... beringovskiy
# Requesting  43 ...... norman wells
# Requesting  44 ...... payo
# Requesting  45 ...... gravdal
# Requesting  46 ...... barrow
# Requesting  47 ...... san
# Requesting  48 ...... ternate
# Requesting  49 ...... sao filipe
# Requesting  50 ...... awbari
# Requesting  51 ...... tabou
# Requesting  52 ...... soyo
# Requesting  566 ...... mayo
# Requesting  567 ...... lumeje
# Requesting  568 ...... mackenzie
# Requesting  569 ...... ricse
# Requesting  570 ...... teofilo otoni
# Requesting  571 ...... kamenskoye .....Empty value, request again...
# Requesting  572 ...... monrovia
# Requesting  573 ...... manacapuru
# Requesting  574 ...... kudahuvadhoo
# Requesting  575 ...... pacifica
# Requesting  576 ...... price
# Requesting  577 ...... dunedin
# Requesting  578 ...... lalomanu .....Empty value, request again...
# Requesting  579 ...... alfredo chaves
# Requesting  580 ...... visby
# Requesting  581 ...... khonuu .....Empty value, request again...
# Requesting  582 ...... la cruz
# Requesting  583 ...... kalino
# Requesting  584 ...... rio grande
# Requesting  585 ...... buritis
# Requesting  586 ...... nemuro
# Requesting  587 ...... the valley
# Requesting  588 ...... sorland
# Requesting  589 ...... kuala terengganu
# Requesting  590 ...... darnah
# Requesting  591 ...... mobaye
# Requesting  592 ...... taoudenni
# Requesting  593 ...... guanica
# Requesting  594 ...... doume
# Requesting  595 ...... zaysan
# Requesting  596 ...... hamilton
# Requesting  597 ...... matadi
# Requesting  598 ...... mutata
# Requesting  599 ...... skibbereen
# Requesting  600 ...... nabire
# Requesting  601 ...... zenzeli
# Requesting  602 ...... emerald
# Requesting  603 ...... turka

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#display the data frame
cities_df = pd.DataFrame({
                            "City" : cities, 
                            "Cloudiness" : Cloudiness,
                            "Country" : Country, 
                            "Date" : Date,
                            "Humidity" : Humidity, 
                            "Lat" : Lat,
                            "Lng" : Lng,
                            "Max_Temp" : Max_Temp,
                            "Wind_Speed" : Wind_Speed
                        })
cities_df
# Out:
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0          eureka         66      US  1595300578        7   40.8 -124.16
# 1            hilo         75      US  1595300777       65  19.73 -155.09
# 2    sentyabrskiy
# 3          albany          3      US  1595300778       87   42.6  -73.97
# 4            hofn         93      IS  1595300584       75  64.25  -15.21
# ..            ...        ...     ...         ...      ...    ...     ...
# 599    skibbereen         40      IE  1595300913       81  51.55   -9.27
# 600        nabire         54      ID  1595300913       61  -3.37  135.48
# 601       zenzeli         74      RU  1595300913       56  45.92   47.05
# 602       emerald        100      AU  1595300914       36 -23.53  148.17
# 603         turka         94      UA  1595300914       97  49.15   23.03
#
#     Max_Temp Wind_Speed
# 0         59       4.43
# 1       82.4      10.29
# 2
# 3      78.01       4.76
# 4      52.61       1.16
# ..       ...        ...
# 599     51.8       8.05
# 600    86.81       5.53
# 601    82.13        5.3
# 602     60.8      13.87
# 603       59         13
#
# [604 rows x 9 columns]

# %%
#save the file into a CSV file in the Resources Folder
cities_df.to_csv("Resources/cities.csv", encoding="utf-8", index=False)

# %%
#Replace the emppty values with Nan=N, then clean the data frame from the NaN values
nan_value = float("NaN")
cities_df.replace("", nan_value, inplace = True)
cities_df.dropna(subset = ["Cloudiness"], inplace = True)
cities_df.dropna(subset = ["Country"], inplace = True)
cities_df.dropna(subset = ["Date"], inplace = True)
cities_df.dropna(subset = ["Humidity"], inplace = True)
cities_df.dropna(subset = ["Lat"], inplace = True)
cities_df.dropna(subset = ["Lng"], inplace = True)
cities_df.dropna(subset = ["Max_Temp"], inplace = True)
cities_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df = cities_df
clean_city_data_df
# Out:
#            City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0        eureka        66.0      US  1.595301e+09       7.0  40.80 -124.16
# 1          hilo        75.0      US  1.595301e+09      65.0  19.73 -155.09
# 3        albany         3.0      US  1.595301e+09      87.0  42.60  -73.97
# 4          hofn        93.0      IS  1.595301e+09      75.0  64.25  -15.21
# 6          zeya        15.0      RU  1.595301e+09      43.0  53.75  127.27
# ..          ...         ...     ...           ...       ...    ...     ...
# 599  skibbereen        40.0      IE  1.595301e+09      81.0  51.55   -9.27
# 600      nabire        54.0      ID  1.595301e+09      61.0  -3.37  135.48
# 601     zenzeli        74.0      RU  1.595301e+09      56.0  45.92   47.05
# 602     emerald       100.0      AU  1.595301e+09      36.0 -23.53  148.17
# 603       turka        94.0      UA  1.595301e+09      97.0  49.15   23.03
#
#      Max_Temp  Wind_Speed
# 0       59.00        4.43
# 1       82.40       10.29
# 3       78.01        4.76
# 4       52.61        1.16
# 6       73.06       12.44
# ..        ...         ...
# 599     51.80        8.05
# 600     86.81        5.53
# 601     82.13        5.30
# 602     60.80       13.87
# 603     59.00       13.00
#
# [551 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max_Temp      551
# Wind_Speed    551
# dtype: int64

# %%
#Save the new clean file in the same folder as the other file
clean_city_data_df.to_csv("Resources/clean_cities.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data_hum_df = clean_city_data_df[clean_city_data_df["Humidity"]>100]
clean_city_data_hum_df
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max_Temp, Wind_Speed]
# Index: []

# %% [markdown]
# There are no cities with Humidity higher tham 100, so we proceed to next step

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# the x and y values (x=lat, y= temp)
lat = clean_city_data_df ["Lat"]
temp = clean_city_data_df ["Max_Temp"]

#create the scatter plt, modify colors, grid and create labels for axis and title
plt.scatter(lat, temp,color="coral", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Latitue vs. Max Temperature (7/20/2020)")
plt.grid()

#save figure as .png file in Figures folder and show the figure on the script
plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data_df ["Lat"]
hum = clean_city_data_df ["Humidity"]

plt.scatter(lat, hum,color="goldenrod", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitue vs. Humidity (7/20/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data_df ["Lat"]
cloud = clean_city_data_df ["Cloudiness"]

plt.scatter(lat, cloud,color="aqua", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitue vs. Cloudiness (7/20/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data_df ["Lat"]
wind = clean_city_data_df ["Wind_Speed"]

plt.scatter(lat, wind,color="lightgreen", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Latitue vs. Wind_Speed (7/20/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
#Northern Hemisphere
northern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]>0]
northern_hemisphere_df
# Out:
#            City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0        eureka        66.0      US  1.595301e+09       7.0  40.80 -124.16
# 1          hilo        75.0      US  1.595301e+09      65.0  19.73 -155.09
# 3        albany         3.0      US  1.595301e+09      87.0  42.60  -73.97
# 4          hofn        93.0      IS  1.595301e+09      75.0  64.25  -15.21
# 6          zeya        15.0      RU  1.595301e+09      43.0  53.75  127.27
# ..          ...         ...     ...           ...       ...    ...     ...
# 596    hamilton        75.0      US  1.595301e+09      78.0  39.18  -84.53
# 598      mutata       100.0      CO  1.595301e+09      84.0   7.24  -76.44
# 599  skibbereen        40.0      IE  1.595301e+09      81.0  51.55   -9.27
# 601     zenzeli        74.0      RU  1.595301e+09      56.0  45.92   47.05
# 603       turka        94.0      UA  1.595301e+09      97.0  49.15   23.03
#
#      Max_Temp  Wind_Speed
# 0       59.00        4.43
# 1       82.40       10.29
# 3       78.01        4.76
# 4       52.61        1.16
# 6       73.06       12.44
# ..        ...         ...
# 596     81.00        3.36
# 598     75.47        0.76
# 599     51.80        8.05
# 601     82.13        5.30
# 603     59.00       13.00
#
# [383 rows x 9 columns]

# %%
#Southern Hemisphere
southern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]<0]
southern_hemisphere_df
# Out:
#             City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 8          bluff        97.0      NZ  1.595301e+09      77.0 -46.60  168.33
# 12   port alfred         0.0      ZA  1.595301e+09      68.0 -33.59   26.89
# 13        atuona        35.0      PF  1.595301e+09      78.0  -9.80 -139.03
# 14      bengkulu        78.0      ID  1.595301e+09      62.0  -3.80  102.27
# 15       ushuaia         0.0      AR  1.595300e+09     100.0 -54.80  -68.30
# ..           ...         ...     ...           ...       ...    ...     ...
# 584   rio grande       100.0      BR  1.595301e+09      86.0 -32.03  -52.10
# 585      buritis         6.0      BR  1.595301e+09      73.0 -15.62  -46.42
# 597       matadi        68.0      CD  1.595301e+09      79.0  -5.82   13.45
# 600       nabire        54.0      ID  1.595301e+09      61.0  -3.37  135.48
# 602      emerald       100.0      AU  1.595301e+09      36.0 -23.53  148.17
#
#      Max_Temp  Wind_Speed
# 8       52.02        6.38
# 12      57.67        3.60
# 13      80.40       18.41
# 14      85.28        3.29
# 15      28.40        5.82
# ..        ...         ...
# 584     64.00        7.94
# 585     62.87        2.01
# 597     71.19        4.83
# 600     86.81        5.53
# 602     60.80       13.87
#
# [168 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_temp)
n_lat = northern_hemisphere_df ["Lat"]
n_temp = northern_hemisphere_df ["Max_Temp"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_temp)
regress_values = n_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

#create the plot and annotate the linear equation
plt.scatter(n_lat, n_temp,color="coral", edgecolors="grey", alpha=0.75)
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(50,80), fontsize = 15, color = "red")

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Northern Hemisphere Latitue vs. Max Temperature (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Temperature.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.3762x + 85.837
#  R-squared is 0.34916739821176335

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_temp)
s_lat = southern_hemisphere_df ["Lat"]
s_temp = southern_hemisphere_df ["Max_Temp"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_temp)
regress_values = s_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,30), fontsize = 15, color = "red")
plt.scatter(s_lat, s_temp,color="coral", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Southern Hemisphere Latitue vs. Max Temperature (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Temperature.png")
plt.show()
# Out:
#  Linear Equation is : y = 0.7379x + 79.7975
#  R-squared is 0.5388108056424146

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_hum)
n_lat = northern_hemisphere_df ["Lat"]
n_hum = northern_hemisphere_df["Humidity"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_hum)
regress_values = n_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(20,20), fontsize = 15, color = "red")
plt.scatter(n_lat, n_hum,color="goldenrod", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere Latitue vs. Humidity (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Humidity.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.1366x + 75.6265
#  R-squared is 0.015314666328334104

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_hum)
s_lat = southern_hemisphere_df ["Lat"]
s_hum = southern_hemisphere_df ["Humidity"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_hum )
regress_values = s_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,50), fontsize = 15, color = "red")
plt.scatter(s_lat,s_hum,color="goldenrod", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere Latitue vs. Humidity (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Humidity.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.1215x + 66.7765
#  R-squared is 0.007189117604029538

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_cloud)
n_lat = northern_hemisphere_df ["Lat"]
n_cloud = northern_hemisphere_df ["Cloudiness"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_cloud)
regress_values = n_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(6,10), fontsize = 15, color = "red")
plt.scatter(n_lat, n_cloud,color="aqua", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere  Latitue vs. Cloudiness (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.1749x + 60.6767
#  R-squared is 0.007429483200744079

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_cloud)
s_lat = southern_hemisphere_df ["Lat"]
s_cloud = southern_hemisphere_df ["Cloudiness"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_cloud)
regress_values = s_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,10), fontsize = 15, color = "red")
plt.scatter(s_lat, s_cloud,color="aqua", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere  Latitue vs. Cloudiness (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#  Linear Equation is : y = -0.2165x + 41.8123
#  R-squared is 0.005460777503466731

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_wind)
n_lat = northern_hemisphere_df ["Lat"]
n_wind = northern_hemisphere_df ["Wind_Speed"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_wind)
regress_values = n_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(6,10), fontsize = 15, color = "red")
plt.scatter(n_lat, n_wind,color="lightgreen", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Northern Hemisphere Latitue vs. Wind_Speed (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Wind.png")
plt.show()
# Out:
#  Linear Equation is : y = 0.0129x + 6.6357
#  R-squared is 0.002727050846927938

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_wind)
s_lat = southern_hemisphere_df ["Lat"]
s_wind = southern_hemisphere_df ["Wind_Speed"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat,s_wind)
regress_values = s_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-20,10), fontsize = 15, color = "red")
plt.scatter(s_lat, s_wind,color="lightgreen", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Southern Hemisphere Latitue vs. Wind_Speed (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Wind")
plt.show()
# Out:
#  Linear Equation is : y = -0.0269x + 6.8256
#  R-squared is 0.004765086120059477
