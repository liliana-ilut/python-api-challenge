# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt  

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low = -90, high = 90, size=1500)
lngs = np.random.uniform(low = -180, high = 180, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 639

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 0
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

print(f"Beginning Data Retrieval")
print(f"------------------------------")
for city in cities:
        url = (f'https://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}')
#         print(url)
        weather_response = requests.get(url)
        weather_json = weather_response.json()
#         print(weather_json)
        try: 
            Cloudiness.append(weather_json['clouds']["all"])
            Country.append(weather_json['sys']["country"])
            Date.append(weather_json["dt"])
            Humidity.append(weather_json["main"]['humidity'])
            Lat.append(weather_json["coord"]['lat'])
            Lng.append(weather_json["coord"]['lon'])
            Max_Temp.append(weather_json["main"]['temp_max'])
            Wind_Speed.append(weather_json["wind"]['speed'])
            print( "Requesting " , count,"......" ,city)
            count = count + 1
            
        except KeyError:
        
            Cloudiness.append("")
            Country.append("")
            Date.append("")
            Humidity.append("")
            Lat.append("")
            Lng.append("")
            Max_Temp.append("")
            Wind_Speed.append("")
            print("Requesting " , count,"......" ,city, ".....Empty value, request again...")
            count = count + 1
# Out:
# Beginning Data Retrieval
# ------------------------------
# Requesting  0 ...... rikitea
# Requesting  1 ...... bredasdorp
# Requesting  2 ...... bluff
# Requesting  3 ...... butaritari
# Requesting  4 ...... mecca
# Requesting  5 ...... vaini
# Requesting  6 ...... thompson
# Requesting  7 ...... talcahuano
# Requesting  8 ...... nevsehir
# Requesting  9 ...... khatanga
# Requesting  10 ...... belushya guba .....Empty value, try again...
# Requesting  11 ...... bandarbeyla
# Requesting  12 ...... hilo
# Requesting  13 ...... busselton
# Requesting  14 ...... amazar
# Requesting  15 ...... moville
# Requesting  16 ...... tabuk
# Requesting  17 ...... mahebourg
# Requesting  18 ...... barentsburg .....Empty value, try again...
# Requesting  19 ...... camocim
# Requesting  20 ...... kodiak
# Requesting  21 ...... puerto ayora
# Requesting  22 ...... flin flon
# Requesting  23 ...... hithadhoo
# Requesting  24 ...... ushuaia
# Requesting  25 ...... punta arenas
# Requesting  26 ...... sentyabrskiy .....Empty value, try again...
# Requesting  27 ...... isangel
# Requesting  28 ...... vostok
# Requesting  29 ...... nikolskoye
# Requesting  30 ...... avarua
# Requesting  31 ...... zhigalovo
# Requesting  32 ...... arroyo
# Requesting  33 ...... geraldton
# Requesting  34 ...... cayenne
# Requesting  35 ...... san patricio
# Requesting  36 ...... albany
# Requesting  37 ...... illoqqortoormiut .....Empty value, try again...
# Requesting  38 ...... ahraura
# Requesting  39 ...... isoka
# Requesting  40 ...... saint-philippe
# Requesting  41 ...... rolim de moura .....Empty value, try again...
# Requesting  42 ...... mezen
# Requesting  43 ...... taolanaro .....Empty value, try again...
# Requesting  44 ...... westport
# Requesting  45 ...... zolotinka .....Empty value, try again...
# Requesting  46 ...... alofi
# Requesting  47 ...... san cristobal
# Requesting  48 ...... barbar .....Empty value, try again...
# Requesting  49 ...... mataura
# Requesting  50 ...... stykkisholmur
# Requesting  51 ...... port alfred
# Requesting  52 ...... hermanus
# Requesting  53 ...... upernavik
# Requesting  54 ...... vestmannaeyjar
# Requesting  55 ...... castro
# Requesting  56 ...... broken hill
# Requesting  57 ...... yellowknife
# Requesting  58 ...... kintampo
# Requesting  59 ...... college
# Requesting  60 ...... narrabri
# Requesting  61 ...... ponta do sol
# Requesting  62 ...... ngunguru
# Requesting  63 ...... attawapiskat .....Empty value, try again...
# Requesting  64 ...... khonuu .....Empty value, try again...
# Requesting  65 ...... qaanaaq
# Requesting  66 ...... cartagena
# Requesting  67 ...... kapaa
# Requesting  68 ...... atar
# Requesting  69 ...... beloha
# Requesting  70 ...... lorengau
# Requesting  71 ...... itamarandiba
# Requesting  72 ...... margate
# Requesting  73 ...... sibolga
# Requesting  74 ...... moose factory
# Requesting  75 ...... vaitupu .....Empty value, try again...
# Requesting  76 ...... nuuk
# Requesting  77 ...... mount gambier
# Requesting  78 ...... whyalla
# Requesting  79 ...... buta
# Requesting  80 ...... ribeira grande
# Requesting  81 ...... pilar
# Requesting  82 ...... bilibino
# Requesting  83 ...... ostrovnoy
# Requesting  84 ...... yazman
# Requesting  85 ...... alice springs
# Requesting  86 ...... henties bay
# Requesting  87 ...... east london
# Requesting  88 ...... bubaque
# Requesting  89 ...... ewa beach
# Requesting  90 ...... torres
# Requesting  91 ...... derzhavinsk
# Requesting  92 ...... tarancon
# Requesting  93 ...... waitati
# Requesting  94 ...... nome
# Requesting  95 ...... portland
# Requesting  96 ...... durban
# Requesting  97 ...... rundu
# Requesting  98 ...... torbay
# Requesting  99 ...... makinsk
# Requesting  100 ...... lukovetskiy
# Requesting  101 ...... port elizabeth
# Requesting  102 ...... barrow
# Requesting  103 ...... leonidion .....Empty value, try again...
# Requesting  104 ...... cabo san lucas
# Requesting  105 ...... north bend
# Requesting  106 ...... chuy
# Requesting  107 ...... lakes entrance
# Requesting  108 ...... san andres
# Requesting  109 ...... caravelas
# Requesting  110 ...... cidreira
# Requesting  111 ...... rochegda
# Requesting  112 ...... shimoda
# Requesting  113 ...... sierpc
# Requesting  114 ...... port moresby
# Requesting  115 ...... arraial do cabo
# Requesting  116 ...... merauke
# Requesting  117 ...... port lincoln
# Requesting  118 ...... victoria
# Requesting  119 ...... kaitangata
# Requesting  120 ...... itarema
# Requesting  121 ...... mogadishu
# Requesting  122 ...... tuktoyaktuk
# Requesting  123 ...... hami
# Requesting  124 ...... yeletskiy .....Empty value, try again...
# Requesting  125 ...... bambous virieux
# Requesting  126 ...... cape town
# Requesting  127 ...... el granzal .....Empty value, try again...
# Requesting  128 ...... olafsvik
# Requesting  129 ...... kumluca
# Requesting  130 ...... plakhtiyivka
# Requesting  131 ...... new glasgow
# Requesting  132 ...... saint-joseph
# Requesting  133 ...... vardo
# Requesting  134 ...... cavalcante
# Requesting  135 ...... chara
# Requesting  136 ...... saleaula .....Empty value, try again...
# Requesting  137 ...... san luis de palenque
# Requesting  138 ...... kudahuvadhoo
# Requesting  139 ...... orthez
# Requesting  140 ...... corcoran
# Requesting  141 ...... husavik
# Requesting  142 ...... macaracas
# Requesting  143 ...... afmadu .....Empty value, try again...
# Requesting  144 ...... hamilton
# Requesting  145 ...... grand centre .....Empty value, try again...
# Requesting  146 ...... vesoul
# Requesting  147 ...... salta
# Requesting  148 ...... ulladulla
# Requesting  149 ...... isabela
# Requesting  150 ...... doha
# Requesting  151 ...... te anau
# Requesting  152 ...... los llanos de aridane
# Requesting  153 ...... jamestown
# Requesting  154 ...... avera
# Requesting  155 ...... songea
# Requesting  156 ...... cap malheureux
# Requesting  157 ...... the valley
# Requesting  158 ...... magdagachi
# Requesting  159 ...... bathsheba
# Requesting  160 ...... longyearbyen
# Requesting  161 ...... atuona
# Requesting  162 ...... katsuura
# Requesting  163 ...... gorontalo
# Requesting  164 ...... lincoln
# Requesting  165 ...... walvis bay
# Requesting  166 ...... kieta
# Requesting  167 ...... maldonado
# Requesting  168 ...... brookhaven
# Requesting  169 ...... nelson bay
# Requesting  170 ...... bandiagara
# Requesting  171 ...... mehamn
# Requesting  172 ...... norman wells
# Requesting  173 ...... manado
# Requesting  174 ...... atbasar
# Requesting  175 ...... worland
# Requesting  176 ...... liverpool
# Requesting  177 ...... zyryanskoye
# Requesting  178 ...... tingi
# Requesting  179 ...... pangody
# Requesting  180 ...... fredonia
# Requesting  181 ...... ixtapa
# Requesting  182 ...... petropavlovsk-kamchatskiy
# Requesting  183 ...... saint-pierre
# Requesting  184 ...... manakara
# Requesting  185 ...... campos belos
# Requesting  186 ...... kyra
# Requesting  187 ...... fortuna
# Requesting  188 ...... aguadilla
# Requesting  189 ...... nizhneyansk .....Empty value, try again...
# Requesting  190 ...... mar del plata
# Requesting  191 ...... sambava
# Requesting  192 ...... mys shmidta .....Empty value, try again...
# Requesting  193 ...... okha
# Requesting  194 ...... mrirt .....Empty value, try again...
# Requesting  195 ...... yomitan .....Empty value, try again...
# Requesting  196 ...... watsa
# Requesting  197 ...... souillac
# Requesting  198 ...... auki
# Requesting  199 ...... wewak
# Requesting  200 ...... zhoucheng
# Requesting  201 ...... lagoa
# Requesting  202 ...... esperance
# Requesting  203 ...... buala
# Requesting  204 ...... labuhan
# Requesting  205 ...... constitucion
# Requesting  206 ...... mudgee
# Requesting  207 ...... atambua
# Requesting  208 ...... mareeba
# Requesting  209 ...... grand gaube
# Requesting  210 ...... ban tak
# Requesting  211 ...... bulgan
# Requesting  212 ...... ballina
# Requesting  213 ...... hobart
# Requesting  214 ...... chokurdakh
# Requesting  215 ...... new norfolk
# Requesting  216 ...... paka
# Requesting  217 ...... sorland
# Requesting  218 ...... shihezi
# Requesting  219 ...... bokspits .....Empty value, try again...
# Requesting  220 ...... barsovo
# Requesting  221 ...... santa cruz
# Requesting  222 ...... vagur
# Requesting  223 ...... grand river south east .....Empty value, try again...
# Requesting  224 ...... saint george
# Requesting  225 ...... orumiyeh
# Requesting  226 ...... jibuti
# Requesting  227 ...... longhua
# Requesting  228 ...... uyemskiy
# Requesting  229 ...... ouesso
# Requesting  230 ...... adrar
# Requesting  231 ...... nishihara
# Requesting  232 ...... nalut
# Requesting  233 ...... ericeira
# Requesting  234 ...... huallanca
# Requesting  235 ...... san vicente
# Requesting  236 ...... pangnirtung
# Requesting  237 ...... tambopata
# Requesting  238 ...... labutta .....Empty value, try again...
# Requesting  239 ...... warqla .....Empty value, try again...
# Requesting  240 ...... babati
# Requesting  241 ...... huancabamba
# Requesting  242 ...... tsihombe .....Empty value, try again...
# Requesting  243 ...... qunduz
# Requesting  244 ...... lebu
# Requesting  245 ...... camacha
# Requesting  246 ...... inhambane
# Requesting  247 ...... buchanan
# Requesting  248 ...... yakovlevka
# Requesting  249 ...... wahpeton
# Requesting  250 ...... ilebo
# Requesting  251 ...... azuga
# Requesting  252 ...... lagoa vermelha
# Requesting  253 ...... maraba
# Requesting  254 ...... coquimbo
# Requesting  255 ...... bethel
# Requesting  256 ...... magistralnyy
# Requesting  257 ...... mentok .....Empty value, try again...
# Requesting  258 ...... grindavik
# Requesting  259 ...... yar-sale
# Requesting  260 ...... marrakesh
# Requesting  261 ...... ilulissat
# Requesting  262 ...... sisimiut
# Requesting  263 ...... kennett
# Requesting  264 ...... bon accord
# Requesting  265 ...... alotau .....Empty value, try again...
# Requesting  266 ...... sal rei
# Requesting  267 ...... agirish
# Requesting  268 ...... saldanha
# Requesting  269 ...... lagunas
# Requesting  270 ...... batagay-alyta
# Requesting  271 ...... pangkalanbuun
# Requesting  272 ...... lavrentiya
# Requesting  273 ...... saskylakh
# Requesting  274 ...... morondava
# Requesting  275 ...... upington
# Requesting  276 ...... iqaluit
# Requesting  277 ...... vao
# Requesting  278 ...... carutapera
# Requesting  279 ...... livingston
# Requesting  280 ...... kuche .....Empty value, try again...
# Requesting  281 ...... nizhniy tsasuchey
# Requesting  282 ...... quang ngai
# Requesting  283 ...... gamba
# Requesting  284 ...... mount isa
# Requesting  285 ...... catio
# Requesting  286 ...... hasaki
# Requesting  287 ...... luebo
# Requesting  288 ...... ancud
# Requesting  289 ...... aklavik
# Requesting  290 ...... baykit
# Requesting  291 ...... tumannyy .....Empty value, try again...
# Requesting  292 ...... omsukchan
# Requesting  293 ...... khani
# Requesting  294 ...... comodoro rivadavia
# Requesting  295 ...... lokhvytsya
# Requesting  296 ...... tasiilaq
# Requesting  297 ...... correntina
# Requesting  298 ...... ilhabela
# Requesting  299 ...... tongliao
# Requesting  300 ...... roseburg
# Requesting  301 ...... dalbandin
# Requesting  302 ...... hualmay
# Requesting  303 ...... pytalovo
# Requesting  304 ...... coronado
# Requesting  305 ...... las tunas
# Requesting  306 ...... richard toll .....Empty value, try again...
# Requesting  307 ...... taburi .....Empty value, try again...
# Requesting  308 ...... jeremie
# Requesting  309 ...... laguna
# Requesting  310 ...... pevek
# Requesting  311 ...... neiafu
# Requesting  312 ...... babanusah .....Empty value, try again...
# Requesting  313 ...... radebeul
# Requesting  314 ...... rawson
# Requesting  315 ...... fort nelson
# Requesting  316 ...... chimore
# Requesting  317 ...... mitsamiouli
# Requesting  318 ...... airai
# Requesting  319 ...... lethem
# Requesting  320 ...... dikson
# Requesting  321 ...... kilindoni
# Requesting  322 ...... malwan .....Empty value, try again...
# Requesting  323 ...... faanui
# Requesting  324 ...... teeli
# Requesting  325 ...... pousat .....Empty value, try again...
# Requesting  326 ...... copiapo
# Requesting  327 ...... pisco
# Requesting  328 ...... cadca
# Requesting  329 ...... imbituba
# Requesting  330 ...... nizwa
# Requesting  331 ...... luderitz
# Requesting  332 ...... petrozavodsk
# Requesting  333 ...... guerrero negro
# Requesting  334 ...... shchelyayur .....Empty value, try again...
# Requesting  335 ...... bilma
# Requesting  336 ...... synya
# Requesting  337 ...... gomez palacio
# Requesting  338 ...... otane
# Requesting  339 ...... amga
# Requesting  340 ...... kushima
# Requesting  341 ...... ascension
# Requesting  342 ...... asau
# Requesting  343 ...... pecos
# Requesting  344 ...... blagoyevo
# Requesting  345 ...... poum
# Requesting  346 ...... broome
# Requesting  347 ...... sahrak .....Empty value, try again...
# Requesting  348 ...... farafangana
# Requesting  349 ...... thunder bay
# Requesting  350 ...... amderma .....Empty value, try again...
# Requesting  351 ...... fergus falls
# Requesting  352 ...... burica .....Empty value, try again...
# Requesting  353 ...... cabedelo
# Requesting  354 ...... novyy urgal
# Requesting  355 ...... hambantota
# Requesting  356 ...... meiktila
# Requesting  357 ...... ko samui
# Requesting  358 ...... ampanihy
# Requesting  359 ...... west plains
# Requesting  360 ...... kahului
# Requesting  361 ...... kavaratti
# Requesting  362 ...... ugep
# Requesting  363 ...... sao filipe
# Requesting  364 ...... anadyr
# Requesting  365 ...... cherskiy
# Requesting  366 ...... naze
# Requesting  367 ...... port hawkesbury
# Requesting  368 ...... leningradskiy
# Requesting  369 ...... marks
# Requesting  370 ...... mugur-aksy
# Requesting  371 ...... kavieng
# Requesting  372 ...... arkhangelskoye
# Requesting  373 ...... arman
# Requesting  374 ...... milkovo
# Requesting  375 ...... dingle
# Requesting  376 ...... vermilion
# Requesting  377 ...... ocean city
# Requesting  378 ...... salalah
# Requesting  379 ...... sinnamary
# Requesting  380 ...... japura
# Requesting  381 ...... tura
# Requesting  382 ...... koboldo .....Empty value, try again...
# Requesting  383 ...... tromso
# Requesting  384 ...... verkhoyansk
# Requesting  385 ...... barawe .....Empty value, try again...
# Requesting  386 ...... georgetown
# Requesting  387 ...... sergiyevsk
# Requesting  388 ...... pitimbu
# Requesting  389 ...... clyde river
# Requesting  390 ...... port hedland
# Requesting  391 ...... maningrida
# Requesting  392 ...... seoul
# Requesting  393 ...... carnarvon
# Requesting  394 ...... gushikawa
# Requesting  395 ...... sala consilina
# Requesting  396 ...... arlit
# Requesting  397 ...... port-cartier
# Requesting  398 ...... hokitika
# Requesting  399 ...... kalmunai
# Requesting  400 ...... erkrath
# Requesting  401 ...... kununurra
# Requesting  402 ...... kenora
# Requesting  403 ...... balabac
# Requesting  404 ...... sakakah
# Requesting  405 ...... osorno
# Requesting  406 ...... alamosa
# Requesting  407 ...... liberal
# Requesting  408 ...... ihosy
# Requesting  409 ...... quatre cocos
# Requesting  410 ...... kamarion
# Requesting  411 ...... half moon bay
# Requesting  412 ...... riyadh
# Requesting  413 ...... beringovskiy
# Requesting  414 ...... gornopravdinsk
# Requesting  415 ...... carolina
# Requesting  416 ...... nettetal
# Requesting  417 ...... itoman
# Requesting  418 ...... sitka
# Requesting  419 ...... narsaq
# Requesting  420 ...... samusu .....Empty value, try again...
# Requesting  421 ...... stephenville
# Requesting  422 ...... ust-tsilma
# Requesting  423 ...... kysyl-syr
# Requesting  424 ...... korla
# Requesting  425 ...... tabou
# Requesting  426 ...... weston
# Requesting  427 ...... siilinjarvi
# Requesting  428 ...... lingyuan
# Requesting  429 ...... mishan
# Requesting  430 ...... lambarene
# Requesting  431 ...... el tocuyo
# Requesting  432 ...... kirkconnel
# Requesting  433 ...... hun
# Requesting  434 ...... rio grande
# Requesting  435 ...... lundazi
# Requesting  436 ...... linqing
# Requesting  437 ...... prado
# Requesting  438 ...... lata
# Requesting  439 ...... hofn
# Requesting  440 ...... meulaboh
# Requesting  441 ...... san pedro
# Requesting  442 ...... cockburn town
# Requesting  443 ...... siirt
# Requesting  444 ...... nanortalik
# Requesting  445 ...... sawakin
# Requesting  446 ...... bay roberts
# Requesting  447 ...... kelowna
# Requesting  448 ...... richards bay
# Requesting  449 ...... gat
# Requesting  450 ...... saint-augustin
# Requesting  451 ...... borzya
# Requesting  452 ...... bereda
# Requesting  453 ...... laela
# Requesting  454 ...... bonnyville
# Requesting  455 ...... socorro
# Requesting  456 ...... manokwari
# Requesting  457 ...... faya
# Requesting  458 ...... diego de almagro
# Requesting  459 ...... safaga
# Requesting  460 ...... catalao
# Requesting  461 ...... paamiut
# Requesting  462 ...... kangaatsiaq
# Requesting  463 ...... jabiru .....Empty value, try again...
# Requesting  464 ...... busembatia
# Requesting  465 ...... namibe
# Requesting  466 ...... tata
# Requesting  467 ...... port hueneme
# Requesting  468 ...... nshamba
# Requesting  469 ...... sao joao da barra
# Requesting  470 ...... tabialan .....Empty value, try again...
# Requesting  471 ...... sao miguel do araguaia
# Requesting  472 ...... north platte
# Requesting  473 ...... taoudenni
# Requesting  474 ...... sidi bin nur
# Requesting  475 ...... marawi
# Requesting  476 ...... bengkulu
# Requesting  477 ...... makakilo city
# Requesting  478 ...... namatanai
# Requesting  479 ...... hanzhong
# Requesting  480 ...... hobyo
# Requesting  481 ...... caxito
# Requesting  482 ...... hohhot
# Requesting  483 ...... sola
# Requesting  484 ...... isla mujeres
# Requesting  485 ...... tornio
# Requesting  486 ...... akola
# Requesting  487 ...... borogontsy
# Requesting  488 ...... port hardy
# Requesting  489 ...... mangaratiba
# Requesting  490 ...... inverell
# Requesting  491 ...... kamaishi
# Requesting  492 ...... rocha
# Requesting  493 ...... coahuayana
# Requesting  494 ...... atlantic beach
# Requesting  495 ...... auchi
# Requesting  496 ...... terra santa
# Requesting  497 ...... ahipara
# Requesting  498 ...... hong gai
# Requesting  499 ...... waipawa
# Requesting  500 ...... nador
# Requesting  501 ...... luganville
# Requesting  502 ...... owando
# Requesting  503 ...... obera
# Requesting  504 ...... billings
# Requesting  505 ...... vasvar
# Requesting  506 ...... tsienyane .....Empty value, try again...
# Requesting  507 ...... san ramon
# Requesting  508 ...... primorsko
# Requesting  509 ...... saint-georges
# Requesting  510 ...... jinchang
# Requesting  511 ...... urumqi
# Requesting  512 ...... carballo
# Requesting  513 ...... ramshir
# Requesting  514 ...... dinguiraye
# Requesting  515 ...... khromtau
# Requesting  516 ...... severo-kurilsk
# Requesting  517 ...... kano
# Requesting  518 ...... danville
# Requesting  519 ...... jining
# Requesting  520 ...... sorvag .....Empty value, try again...
# Requesting  521 ...... kedgwick
# Requesting  522 ...... zhangye
# Requesting  523 ...... chamonix-mont-blanc
# Requesting  524 ...... shache
# Requesting  525 ...... semme
# Requesting  526 ...... bidhuna
# Requesting  527 ...... berlevag
# Requesting  528 ...... balteni
# Requesting  529 ...... maragogi
# Requesting  530 ...... along
# Requesting  531 ...... jaramana .....Empty value, try again...
# Requesting  532 ...... tikrit
# Requesting  533 ...... kungurtug
# Requesting  534 ...... bitung
# Requesting  535 ...... vila velha
# Requesting  536 ...... palabuhanratu .....Empty value, try again...
# Requesting  537 ...... axim
# Requesting  538 ...... sahagun
# Requesting  539 ...... tigzirt
# Requesting  540 ...... cururupu
# Requesting  541 ...... imeni telmana .....Empty value, try again...
# Requesting  542 ...... rumoi
# Requesting  543 ...... iskateley
# Requesting  544 ...... illapel
# Requesting  545 ...... moche
# Requesting  546 ...... banda aceh
# Requesting  547 ...... duz .....Empty value, try again...
# Requesting  548 ...... christchurch
# Requesting  549 ...... belyy yar
# Requesting  550 ...... samarai
# Requesting  551 ...... acapulco
# Requesting  552 ...... moerai
# Requesting  553 ...... russell
# Requesting  554 ...... komsomolskiy
# Requesting  555 ...... sidi ali
# Requesting  556 ...... catuday
# Requesting  557 ...... remiremont
# Requesting  558 ...... zhigansk
# Requesting  559 ...... muscat
# Requesting  560 ...... lazaro cardenas
# Requesting  561 ...... general pico
# Requesting  562 ...... san jeronimo
# Requesting  563 ...... mocambique .....Empty value, try again...
# Requesting  564 ...... xuddur
# Requesting  565 ...... ust-tarka
# Requesting  566 ...... kazalinsk .....Empty value, try again...
# Requesting  567 ...... gurgan .....Empty value, try again...
# Requesting  568 ...... gari
# Requesting  569 ...... kirakira
# Requesting  570 ...... bagalkot
# Requesting  571 ...... mayo
# Requesting  572 ...... marcona .....Empty value, try again...
# Requesting  573 ...... padang
# Requesting  574 ...... taltal
# Requesting  575 ...... la sarre
# Requesting  576 ...... scranton
# Requesting  577 ...... mwingi
# Requesting  578 ...... grootfontein
# Requesting  579 ...... kidal
# Requesting  580 ...... saint-paul
# Requesting  581 ...... teya
# Requesting  582 ...... yulara
# Requesting  583 ...... standerton
# Requesting  584 ...... skibotn
# Requesting  585 ...... hovd
# Requesting  586 ...... kalengwa
# Requesting  587 ...... kruisfontein
# Requesting  588 ...... tautira
# Requesting  589 ...... provideniya
# Requesting  590 ...... solnechnyy
# Requesting  591 ...... san matias
# Requesting  592 ...... chapais
# Requesting  593 ...... aranda de duero
# Requesting  594 ...... chagda .....Empty value, try again...
# Requesting  595 ...... sakaiminato
# Requesting  596 ...... rokytne
# Requesting  597 ...... kamenka
# Requesting  598 ...... gniezno
# Requesting  599 ...... shenjiamen
# Requesting  600 ...... gimli
# Requesting  601 ...... gombong
# Requesting  602 ...... sistranda
# Requesting  603 ...... la ronge
# Requesting  604 ...... hwange
# Requesting  605 ...... sobreira
# Requesting  606 ...... zabaykalsk
# Requesting  607 ...... kholodnyy
# Requesting  608 ...... mazabuka
# Requesting  609 ...... plettenberg bay
# Requesting  610 ...... lompoc
# Requesting  611 ...... galesong
# Requesting  612 ...... gravdal
# Requesting  613 ...... turukhansk
# Requesting  614 ...... nusaybin
# Requesting  615 ...... turayf
# Requesting  616 ...... buraydah
# Requesting  617 ...... srednekolymsk
# Requesting  618 ...... nanlong
# Requesting  619 ...... puerto colombia
# Requesting  620 ...... port blair
# Requesting  621 ...... pundaguitan
# Requesting  622 ...... tiksi
# Requesting  623 ...... nancha
# Requesting  624 ...... ara
# Requesting  625 ...... zhenlai
# Requesting  626 ...... diamantino
# Requesting  627 ...... nouadhibou
# Requesting  628 ...... waingapu
# Requesting  629 ...... yuci
# Requesting  630 ...... sterling
# Requesting  631 ...... pauini
# Requesting  632 ...... pijijiapan
# Requesting  633 ...... talnakh
# Requesting  634 ...... novosokolniki
# Requesting  635 ...... homer
# Requesting  636 ...... ystad
# Requesting  637 ...... weyburn
# Requesting  638 ...... gewane

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#display the data frame
cities_df = pd.DataFrame({
                            "City" : cities, 
                            "Cloudiness" : Cloudiness,
                            "Country" : Country, 
                            "Date" : Date,
                            "Humidity" : Humidity, 
                            "Lat" : Lat,
                            "Lng" : Lng,
                            "Max_Temp" : Max_Temp,
                            "Wind_Speed" : Wind_Speed
                        })
cities_df
# Out:
#               City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0          rikitea         85      PF  1595258006       57 -23.12 -134.97
# 1       bredasdorp          0      ZA  1595258006       77 -34.53   20.04
# 2            bluff        100      NZ  1595257969       83  -46.6  168.33
# 3       butaritari         99      KI  1595257715       67   3.07  172.79
# 4            mecca         30      SA  1595257796       33  21.43   39.83
# ..             ...        ...     ...         ...      ...    ...     ...
# 634  novosokolniki        100      RU  1595258143       62  56.35   30.16
# 635          homer         75      US  1595258143      100  59.64 -151.55
# 636          ystad         19      SE  1595258144       48  55.43   13.82
# 637        weyburn        100      CA  1595258144       85  49.67 -103.85
# 638         gewane         20      ET  1595258144       28  10.17   40.65
#
#     Max_Temp Wind_Speed
# 0      68.47      13.09
# 1       62.6       6.93
# 2         39          3
# 3      82.76       7.67
# 4      94.89       6.85
# ..       ...        ...
# 634    72.88       3.87
# 635    55.99       2.64
# 636     66.2      17.22
# 637       61       7.09
# 638    94.57       7.67
#
# [639 rows x 9 columns]

# %%
#save the file into a CSV file in the Resources Folder
cities_df.to_csv("Resources/cities.csv", encoding="utf-8", index=False)

# %%
#Replace the emppty values with Nan=N, then clean the data frame from the NaN values
nan_value = float("NaN")
cities_df.replace("", nan_value, inplace = True)
cities_df.dropna(subset = ["Cloudiness"], inplace = True)
cities_df.dropna(subset = ["Country"], inplace = True)
cities_df.dropna(subset = ["Date"], inplace = True)
cities_df.dropna(subset = ["Humidity"], inplace = True)
cities_df.dropna(subset = ["Lat"], inplace = True)
cities_df.dropna(subset = ["Lng"], inplace = True)
cities_df.dropna(subset = ["Max_Temp"], inplace = True)
cities_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df = cities_df
clean_city_data_df
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0          rikitea        85.0      PF  1.595258e+09      57.0 -23.12 -134.97
# 1       bredasdorp         0.0      ZA  1.595258e+09      77.0 -34.53   20.04
# 2            bluff       100.0      NZ  1.595258e+09      83.0 -46.60  168.33
# 3       butaritari        99.0      KI  1.595258e+09      67.0   3.07  172.79
# 4            mecca        30.0      SA  1.595258e+09      33.0  21.43   39.83
# ..             ...         ...     ...           ...       ...    ...     ...
# 634  novosokolniki       100.0      RU  1.595258e+09      62.0  56.35   30.16
# 635          homer        75.0      US  1.595258e+09     100.0  59.64 -151.55
# 636          ystad        19.0      SE  1.595258e+09      48.0  55.43   13.82
# 637        weyburn       100.0      CA  1.595258e+09      85.0  49.67 -103.85
# 638         gewane        20.0      ET  1.595258e+09      28.0  10.17   40.65
#
#      Max_Temp  Wind_Speed
# 0       68.47       13.09
# 1       62.60        6.93
# 2       39.00        3.00
# 3       82.76        7.67
# 4       94.89        6.85
# ..        ...         ...
# 634     72.88        3.87
# 635     55.99        2.64
# 636     66.20       17.22
# 637     61.00        7.09
# 638     94.57        7.67
#
# [584 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          584
# Cloudiness    584
# Country       584
# Date          584
# Humidity      584
# Lat           584
# Lng           584
# Max_Temp      584
# Wind_Speed    584
# dtype: int64

# %%
#Save the new clean file in the same folder as the other file
clean_city_data_df.to_csv("Resources/clean_cities.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
clean_city_data_hum_df = clean_city_data_df[clean_city_data_df["Humidity"]>100]
clean_city_data_hum_df
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max_Temp, Wind_Speed]
# Index: []

# %% [markdown]
# There are no cities with Humidity higher tham 100, so we proceed to next step

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat = clean_city_data_df ["Lat"]
temp = clean_city_data_df ["Max_Temp"]

plt.scatter(lat, temp,color="coral", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Latitue vs. Max Temperature (7/19/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data_df ["Lat"]
hum = clean_city_data_df ["Humidity"]

plt.scatter(lat, hum,color="goldenrod", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitue vs. Humidity (7/19/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data_df ["Lat"]
cloud = clean_city_data_df ["Cloudiness"]

plt.scatter(lat, cloud,color="aqua", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitue vs. Cloudiness (7/19/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data_df ["Lat"]
wind = clean_city_data_df ["Wind_Speed"]

plt.scatter(lat, wind,color="lightgreen", edgecolors="grey", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Latitue vs. Wind_Speed (7/19/2020)")
plt.grid()

plt.savefig("Figures/Plot_Lat_vs_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
#Northern Hemisphere
northern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]>0]
northern_hemisphere_df
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 3       butaritari        99.0      KI  1.595258e+09      67.0   3.07  172.79
# 4            mecca        30.0      SA  1.595258e+09      33.0  21.43   39.83
# 6         thompson        40.0      CA  1.595258e+09      60.0  55.74  -97.86
# 8         nevsehir        20.0      TR  1.595258e+09      18.0  38.92   34.67
# 9         khatanga        22.0      RU  1.595258e+09      71.0  71.97  102.50
# ..             ...         ...     ...           ...       ...    ...     ...
# 634  novosokolniki       100.0      RU  1.595258e+09      62.0  56.35   30.16
# 635          homer        75.0      US  1.595258e+09     100.0  59.64 -151.55
# 636          ystad        19.0      SE  1.595258e+09      48.0  55.43   13.82
# 637        weyburn       100.0      CA  1.595258e+09      85.0  49.67 -103.85
# 638         gewane        20.0      ET  1.595258e+09      28.0  10.17   40.65
#
#      Max_Temp  Wind_Speed
# 3       82.76        7.67
# 4       94.89        6.85
# 6       68.00        3.36
# 8      100.40       12.75
# 9       53.58        6.73
# ..        ...         ...
# 634     72.88        3.87
# 635     55.99        2.64
# 636     66.20       17.22
# 637     61.00        7.09
# 638     94.57        7.67
#
# [391 rows x 9 columns]

# %%
#Southern Hemisphere
southern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]<0]
southern_hemisphere_df
# Out:
#                 City  Cloudiness Country          Date  Humidity    Lat  \
# 0            rikitea        85.0      PF  1.595258e+09      57.0 -23.12
# 1         bredasdorp         0.0      ZA  1.595258e+09      77.0 -34.53
# 2              bluff       100.0      NZ  1.595258e+09      83.0 -46.60
# 5              vaini        40.0      TO  1.595258e+09      78.0 -21.20
# 7         talcahuano        75.0      CL  1.595258e+09      87.0 -36.72
# ..               ...         ...     ...           ...       ...    ...
# 609  plettenberg bay         0.0      ZA  1.595258e+09      79.0 -34.05
# 611         galesong        20.0      ID  1.595258e+09      83.0  -5.32
# 626       diamantino         0.0      BR  1.595258e+09      28.0 -14.41
# 628         waingapu         0.0      ID  1.595258e+09      81.0  -9.66
# 631           pauini         0.0      BR  1.595258e+09      54.0  -7.71
#
#         Lng  Max_Temp  Wind_Speed
# 0   -134.97     68.47       13.09
# 1     20.04     62.60        6.93
# 2    168.33     39.00        3.00
# 5   -175.20     71.60       11.41
# 7    -73.12     55.40        8.05
# ..      ...       ...         ...
# 609   23.37     62.60        3.85
# 611  119.37     77.00        4.70
# 626  -56.45     89.28        8.63
# 628  120.26     73.49        8.21
# 631  -66.98     89.26        3.67
#
# [193 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_temp)
n_lat = northern_hemisphere_df ["Lat"]
n_temp = northern_hemisphere_df ["Max_Temp"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_temp)
regress_values = n_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

#create the plot and annotate the linear equation
plt.scatter(n_lat, n_temp,color="coral", edgecolors="grey", alpha=0.75)
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(50,80), fontsize = 15, color = "red")

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Northern Hemisphere Latitue vs. Max Temperature (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Temperature.png")
plt.show()
# Out:
#  R-squared is 0.42611907001035537

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_temp)
s_lat = southern_hemisphere_df ["Lat"]
s_temp = southern_hemisphere_df ["Max_Temp"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_temp)
regress_values = s_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,30), fontsize = 15, color = "red")
plt.scatter(s_lat, s_temp,color="coral", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Southern Hemisphere Latitue vs. Max Temperature (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Temperature.png")
plt.show()
# Out:
# y = 0.7812x + 84.6629
#  R-squared is 0.5645706981905904

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_hum)
n_lat = northern_hemisphere_df ["Lat"]
n_hum = northern_hemisphere_df["Humidity"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_hum)
regress_values = n_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(20,20), fontsize = 15, color = "red")
plt.scatter(n_lat, n_hum,color="goldenrod", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere Latitue vs. Humidity (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Humidity.png")
plt.show()
# Out:
#  R-squared is 0.0009499049463685899

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_hum)
s_lat = southern_hemisphere_df ["Lat"]
s_hum = southern_hemisphere_df ["Humidity"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_hum )
regress_values = s_lat * slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,50), fontsize = 15, color = "red")
plt.scatter(s_lat,s_hum,color="goldenrod", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere Latitue vs. Humidity (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Humidity.png")
plt.show()
# Out:
#  R-squared is 0.024191107390132596

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_cloud)
n_lat = northern_hemisphere_df ["Lat"]
n_cloud = northern_hemisphere_df ["Cloudiness"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_cloud)
regress_values = n_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(6,10), fontsize = 15, color = "red")
plt.scatter(n_lat, n_cloud,color="aqua", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere  Latitue vs. Cloudiness (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#  R-squared is 0.0022919297166730536

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_cloud)
s_lat = southern_hemisphere_df ["Lat"]
s_cloud = southern_hemisphere_df ["Cloudiness"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_cloud)
regress_values = s_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-50,10), fontsize = 15, color = "red")
plt.scatter(s_lat, s_cloud,color="aqua", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere  Latitue vs. Cloudiness (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Cloudiness.png")
plt.show()
# Out:
#  R-squared is 0.027138931789868866

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the x and y values (x=n_lat, y= n_wind)
n_lat = northern_hemisphere_df ["Lat"]
n_wind = northern_hemisphere_df ["Wind_Speed"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_wind)
regress_values = n_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(n_lat,regress_values,"r-")
plt.annotate(line_eq,(6,10), fontsize = 15, color = "red")
plt.scatter(n_lat, n_wind,color="lightgreen", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Northern Hemisphere Latitue vs. Wind_Speed (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_North_Lat_vs_Wind.png")
plt.show()
# Out:
#  R-squared is 0.02558984131214477

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#set the x and y values (x=s_lat, y= s_wind)
s_lat = southern_hemisphere_df ["Lat"]
s_wind = southern_hemisphere_df ["Wind_Speed"]

#create the linear regression equation
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat,s_wind)
regress_values = s_lat* slope + intercept
line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))

# create the plot and annotate the linear equation
plt.plot(s_lat,regress_values,"r-")
plt.annotate(line_eq,(-20,10), fontsize = 15, color = "red")
plt.scatter(s_lat, s_wind,color="lightgreen", edgecolors="grey", alpha=0.75)

#create labels for x & y axis and title
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Southern Hemisphere Latitue vs. Wind_Speed (7/20/2020)")
plt.grid()

#print linear regression and R squrared
print(f" Linear Equation is : {line_eq}")
print(f" R-squared is {rvalue**2}")

#save the figure in Figures folder and show it in the script
plt.savefig("Figures/Regression_South_Lat_vs_Wind")
plt.show()
# Out:
#  R-squared is 0.01000614632292025
