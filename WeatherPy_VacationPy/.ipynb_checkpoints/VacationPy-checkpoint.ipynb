# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
# from config import gkey
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_data_df= pd.read_csv(
    "Resources/clean_cities.csv", dtype="object", encoding="utf-8")

# Visualize
clean_city_data_df
# Out:
#                 City Cloudiness Country          Date Humidity     Lat  \
# 0            te anau      100.0      NZ  1595206482.0     92.0  -45.42
# 1    hostotipaquillo       49.0      MX  1595206482.0     73.0   21.07
# 2         hervey bay        0.0      AU  1595206482.0     46.0   -25.3
# 3        port alfred        0.0      ZA  1595206483.0     49.0  -33.59
# 4             hobart       40.0      AU  1595206218.0     57.0  -42.88
# ..               ...        ...     ...           ...      ...     ...
# 568         heilbron        0.0      ZA  1595206629.0     55.0  -27.28
# 569   cap-aux-meules       20.0      CA  1595206630.0     77.0   47.38
# 570        catamarca        0.0      AR  1595206630.0     57.0  -28.47
# 571            aswan        5.0      EG  1595206630.0     18.0   24.09
# 572          onokhoy       20.0      RU  1595206630.0     48.0   51.93
#
#          Lng Max_Temp Wind_Speed
# 0     167.72    45.81       2.13
# 1    -104.07    73.99       2.71
# 2     152.85     69.8       8.05
# 3      26.89    60.94       6.87
# 4     147.33     48.2      19.46
# ..       ...      ...        ...
# 568    27.97    40.64       10.4
# 569   -61.86     69.8       8.05
# 570   -65.79    60.01       1.01
# 571    32.91    86.23      10.27
# 572   108.07     62.6       6.71
#
# [573 rows x 9 columns]

# %%
#Drop the empty values and clean the table
nan_value = float("NaN")
clean_city_data_df.replace("", nan_value, inplace = True)
clean_city_data_df.dropna(subset = ["Country"], inplace = True)
clean_city_data_df.dropna(subset = ["Cloudiness"], inplace = True)
clean_city_data_df.dropna(subset = ["Date"], inplace = True)
clean_city_data_df.dropna(subset = ["Humidity"], inplace = True)
clean_city_data_df.dropna(subset = ["Lat"], inplace = True)
clean_city_data_df.dropna(subset = ["Lng"], inplace = True)
clean_city_data_df.dropna(subset = ["Max_Temp"], inplace = True)
clean_city_data_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df
# Out:
#                 City Cloudiness Country          Date Humidity     Lat  \
# 0            te anau      100.0      NZ  1595206482.0     92.0  -45.42
# 1    hostotipaquillo       49.0      MX  1595206482.0     73.0   21.07
# 2         hervey bay        0.0      AU  1595206482.0     46.0   -25.3
# 3        port alfred        0.0      ZA  1595206483.0     49.0  -33.59
# 4             hobart       40.0      AU  1595206218.0     57.0  -42.88
# ..               ...        ...     ...           ...      ...     ...
# 568         heilbron        0.0      ZA  1595206629.0     55.0  -27.28
# 569   cap-aux-meules       20.0      CA  1595206630.0     77.0   47.38
# 570        catamarca        0.0      AR  1595206630.0     57.0  -28.47
# 571            aswan        5.0      EG  1595206630.0     18.0   24.09
# 572          onokhoy       20.0      RU  1595206630.0     48.0   51.93
#
#          Lng Max_Temp Wind_Speed
# 0     167.72    45.81       2.13
# 1    -104.07    73.99       2.71
# 2     152.85     69.8       8.05
# 3      26.89    60.94       6.87
# 4     147.33     48.2      19.46
# ..       ...      ...        ...
# 568    27.97    40.64       10.4
# 569   -61.86     69.8       8.05
# 570   -65.79    60.01       1.01
# 571    32.91    86.23      10.27
# 572   108.07     62.6       6.71
#
# [570 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Lat           570
# Lng           570
# Max_Temp      570
# Wind_Speed    570
# dtype: int64

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = clean_city_data_df[["Lat", "Lng"]].astype(float)
humidity = clean_city_data_df["Humidity"].astype(float)
humidity
# Out:
# 0      92.0
# 1      73.0
# 2      46.0
# 3      49.0
# 4      57.0
#        ...
# 568    55.0
# 569    77.0
# 570    57.0
# 571    18.0
# 572    48.0
# Name: Humidity, Length: 570, dtype: float64

# %%
#addig heatmap
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights = humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
plt.savefig("Figures/Heat_Map.png")

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Create the Ideal vacation = Tempretaure between 60 and 85 F, wind speed lower than 10mph, humidity less than 85 % and cloudiness 0

ideal_vacation_df = clean_city_data_df[clean_city_data_df["Max_Temp"] > "60"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Max_Temp"] < "85"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Wind_Speed"] < "10"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Humidity"] < "85"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Cloudiness"] < "3"]
ideal_vacation_df
# Out:
#                     City Cloudiness Country          Date Humidity     Lat  \
# 55              shahreza        0.0      IR  1595206496.0     27.0   32.03
# 74         lakhdenpokhya        0.0      RU  1595206501.0     76.0   61.52
# 85            port blair      100.0      IN  1595206453.0     75.0   11.67
# 96              xunchang      100.0      CN  1595206509.0     74.0   28.45
# 97      monsummano terme        0.0      IT  1595206509.0     46.0   43.87
# 217                altay        0.0      CN  1595206540.0     33.0   47.87
# 236  santiago del estero        0.0      AR  1595206337.0     70.0   -27.8
# 304              kumluca        0.0      TR  1595206564.0     58.0   36.37
# 320             bilibino        0.0      RU  1595206569.0     30.0   68.05
# 342               labrea      100.0      BR  1595206574.0     69.0   -7.26
# 391                 sand        1.0      DE  1595206587.0      6.0    50.0
# 409               tiznit        0.0      MA  1595206525.0     34.0   29.58
# 479                mweka        0.0      CD  1595206607.0     48.0   -4.85
# 556                  gat        0.0      IL  1595206627.0     68.0   31.61
# 570            catamarca        0.0      AR  1595206630.0     57.0  -28.47
#
#         Lng Max_Temp Wind_Speed
# 55    51.88    65.68       0.85
# 74     30.2    64.99       1.74
# 85    92.75    81.93       1.41
# 96   104.72    79.52       1.79
# 97    10.81     68.0       1.21
# 217   88.12    77.31        1.5
# 236  -64.26    71.82       1.92
# 304   30.29    77.56       1.74
# 320  166.44    70.95       1.28
# 342   -64.8    79.03       1.19
# 391    10.6     63.0       1.01
# 409    -9.5    80.82       1.21
# 479   21.57    65.03       1.39
# 556   34.76     77.0       1.16
# 570  -65.79    60.01       1.01

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_vacation_df.loc[:, ["City", "Country", "Lat", "Lng", "Max_Temp"]]
hotel_df["Hotel_Name"] = ""
hotel_df
# Out:
#                     City Country     Lat     Lng Max_Temp Hotel_Name
# 55              shahreza      IR   32.03   51.88    65.68
# 74         lakhdenpokhya      RU   61.52    30.2    64.99
# 85            port blair      IN   11.67   92.75    81.93
# 96              xunchang      CN   28.45  104.72    79.52
# 97      monsummano terme      IT   43.87   10.81     68.0
# 217                altay      CN   47.87   88.12    77.31
# 236  santiago del estero      AR   -27.8  -64.26    71.82
# 304              kumluca      TR   36.37   30.29    77.56
# 320             bilibino      RU   68.05  166.44    70.95
# 342               labrea      BR   -7.26   -64.8    79.03
# 391                 sand      DE    50.0    10.6     63.0
# 409               tiznit      MA   29.58    -9.5    80.82
# 479                mweka      CD   -4.85   21.57    65.03
# 556                  gat      IL   31.61   34.76     77.0
# 570            catamarca      AR  -28.47  -65.79    60.01

# %%
maps_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
for index, row in hotel_df.iterrows():
    # pull in needed data
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    params["location"] = f"{lat},{lng}"
    print(f"display the results {index}: {city_name}.")
    response = requests.get(maps_url, params=params).json()
    final_results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Nearby hotel in {city_name} is {final_results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = final_results[0]['name']

    # if there is no hotel available print this
    except (KeyError, IndexError):
        print("Not a hotel... next.")
        
        print("-------End of Search-------")
# Out:
# display the results 55: هتل و رستوران منتظران.
# Not a hotel... next.
# -------End of Search-------
# display the results 74: Karlen.
# Not a hotel... next.
# -------End of Search-------
# display the results 85: Hotel RNP.
# Not a hotel... next.
# -------End of Search-------
# display the results 96: Xinlin Business Hotel.
# Not a hotel... next.
# -------End of Search-------
# display the results 97: Grand Hotel Tettuccio.
# Not a hotel... next.
# -------End of Search-------
# display the results 217: Altay Regional Tourist Hotel.
# Not a hotel... next.
# -------End of Search-------
# display the results 236: Hotel Coventry.
# Not a hotel... next.
# -------End of Search-------
# display the results 304: TurkuazKöy.
# Not a hotel... next.
# -------End of Search-------
# display the results 320: Profilaktoriy Baes.
# Not a hotel... next.
# -------End of Search-------
# display the results 342: Dannys Hotel.
# Not a hotel... next.
# -------End of Search-------
# display the results 391: Hotel Haus am Wald.
# Not a hotel... next.
# -------End of Search-------
# display the results 409: tiznit.
# Not a hotel... next.
# -------End of Search-------
# display the results 479: mweka.
# Not a hotel... next.
# -------End of Search-------
# display the results 556: Desert Gat.
# Not a hotel... next.
# -------End of Search-------
# display the results 570: Amerian Catamarca Park Hotel.
# Not a hotel... next.
# -------End of Search-------

# %%
hotel_df
# Out:
#                              City                       Country  \
# 55          هتل و رستوران منتظران         هتل و رستوران منتظران
# 74                         Karlen                        Karlen
# 85                      Hotel RNP                     Hotel RNP
# 96          Xinlin Business Hotel         Xinlin Business Hotel
# 97          Grand Hotel Tettuccio         Grand Hotel Tettuccio
# 217  Altay Regional Tourist Hotel  Altay Regional Tourist Hotel
# 236                Hotel Coventry                Hotel Coventry
# 304                    TurkuazKöy                    TurkuazKöy
# 320            Profilaktoriy Baes            Profilaktoriy Baes
# 342                  Dannys Hotel                  Dannys Hotel
# 391            Hotel Haus am Wald            Hotel Haus am Wald
# 409                        tiznit                            MA
# 479                         mweka                            CD
# 556                    Desert Gat                    Desert Gat
# 570  Amerian Catamarca Park Hotel  Amerian Catamarca Park Hotel
#
#                               Lat                           Lng  \
# 55          هتل و رستوران منتظران         هتل و رستوران منتظران
# 74                         Karlen                        Karlen
# 85                      Hotel RNP                     Hotel RNP
# 96          Xinlin Business Hotel         Xinlin Business Hotel
# 97          Grand Hotel Tettuccio         Grand Hotel Tettuccio
# 217  Altay Regional Tourist Hotel  Altay Regional Tourist Hotel
# 236                Hotel Coventry                Hotel Coventry
# 304                    TurkuazKöy                    TurkuazKöy
# 320            Profilaktoriy Baes            Profilaktoriy Baes
# 342                  Dannys Hotel                  Dannys Hotel
# 391            Hotel Haus am Wald            Hotel Haus am Wald
# 409                         29.58                          -9.5
# 479                         -4.85                         21.57
# 556                    Desert Gat                    Desert Gat
# 570  Amerian Catamarca Park Hotel  Amerian Catamarca Park Hotel
#
#                          Max_Temp                    Hotel_Name  \
# 55          هتل و رستوران منتظران         هتل و رستوران منتظران
# 74                         Karlen                        Karlen
# 85                      Hotel RNP                     Hotel RNP
# 96          Xinlin Business Hotel         Xinlin Business Hotel
# 97          Grand Hotel Tettuccio         Grand Hotel Tettuccio
# 217  Altay Regional Tourist Hotel  Altay Regional Tourist Hotel
# 236                Hotel Coventry                Hotel Coventry
# 304                    TurkuazKöy                    TurkuazKöy
# 320            Profilaktoriy Baes            Profilaktoriy Baes
# 342                  Dannys Hotel                  Dannys Hotel
# 391            Hotel Haus am Wald            Hotel Haus am Wald
# 409                         80.82
# 479                         65.03
# 556                    Desert Gat                    Desert Gat
# 570  Amerian Catamarca Park Hotel  Amerian Catamarca Park Hotel
#
#                        Hotel Name
# 55          هتل و رستوران منتظران
# 74                         Karlen
# 85                      Hotel RNP
# 96          Xinlin Business Hotel
# 97          Grand Hotel Tettuccio
# 217  Altay Regional Tourist Hotel
# 236                Hotel Coventry
# 304                    TurkuazKöy
# 320            Profilaktoriy Baes
# 342                  Dannys Hotel
# 391            Hotel Haus am Wald
# 409                           NaN
# 479                           NaN
# 556                    Desert Gat
# 570  Amerian Catamarca Park Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
hotel_info
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>Jindu Garden Grand Hotel</dd>\n<dt>City</dt><dd>linfen</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel San Diego Suites São Gotardo</dd>\n<dt>City</dt><dd>sao gotardo</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Colonia Park Hotel () Three Star Hotel</dd>\n<dt>City</dt><dd>sebinkarahisar</dd>\n<dt>Country</dt><dd>TR</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Name</dt><dd>Sainte Marie des Ollieux : Chambres d'hôtes B&B et gîte à la campagne - Aude Languedoc Roussillon</dd>\n<dt>City</dt><dd>narbonne</dd>\n<dt>Country</dt><dd>FR</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Name</dt><dd>Century Dynasty Hotel</dd>\n<dt>City</dt><dd>xuanhua</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>La Bamba</dd>\n<dt>City</dt><dd>navalmoral de la mata</dd>\n<dt>Country</dt><dd>ES</dd>\n</dl>\n']

# %%
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()                             
fig.add_layer(marker_layer)
fig.add_layer(heat_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-e8ceee490c83> in <module>
# ----> 1 markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
#       2 fig = gmaps.figure()
#       3 fig.add_layer(marker_layer)
#       4 fig.add_layer(heat_layer)
#       5 # plt.savefig("../output_data/heatmap2.png")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     552     """
#     553     marker_options = _marker_layer_options(
# --> 554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
#     556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _marker_layer_options(locations, hover_text, label, info_box_content, display_info_box)
#     319
#     320     info_box_options = _info_box_option_lists(
# --> 321         number_markers, info_box_content, display_info_box)
#     322
#     323     marker_options.update(info_box_options)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _info_box_option_lists(number_markers, info_box_content, display_info_box)
#     252     for imarker in range(number_markers):
#     253         if display_info_box[imarker] is None:
# --> 254             is_content_empty = (info_box_content[imarker] is None)
#     255             if is_content_empty:
#     256                 display_info_box[imarker] = False
#
# IndexError: list index out of range

# %%
# Add marker layer ontop of heat map
hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info )
gig = gmaps.figure()
fig.add_layer(markers)
fig.add_layer(heat_layer)
fig
# markers = gmaps.marker_layer(locations, info_box_content = hotel_info)

# Display figure
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-aaac6a7dd1cb> in <module>
#       1 # Add marker layer ontop of heat map
# ----> 2 hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info )
#       3 gig = gmaps.figure()
#       4 fig.add_layer(markers)
#       5 fig.add_layer(heat_layer)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
