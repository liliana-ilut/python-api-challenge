# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
# from config import gkey
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_data_df= pd.read_csv(
    "Resources/clean_cities.csv", dtype="object", encoding="utf-8")

# Visualize
clean_city_data_df
# Out:
#           City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0       albany       97.0      US  1595212502.0     94.0    42.6  -73.97
# 1         zeya      100.0      RU  1595212795.0     87.0   53.75  127.27
# 2       vostok      100.0      RU  1595212796.0     30.0   46.49  135.88
# 3    busselton        0.0      AU  1595212625.0     54.0  -33.65  115.33
# 4       castro        0.0      BR  1595212634.0     90.0  -24.79  -50.01
# ..         ...        ...     ...           ...      ...     ...     ...
# 566      pilar       75.0      BR  1595212927.0     94.0    -9.6  -35.96
# 567   zhigansk      100.0      RU  1595212927.0     69.0   66.77  123.37
# 568    bubaque      100.0      GW  1595212927.0     85.0   11.28  -15.83
# 569  ann arbor       59.0      US  1595212774.0     96.0   42.28  -83.74
# 570  maracaibo       88.0      VE  1595212649.0     79.0   10.63  -71.64
#
#     Max_Temp Wind_Speed
# 0      80.01       4.36
# 1      70.38      10.38
# 2      81.81       7.85
# 3       61.0      10.76
# 4      54.81       3.62
# ..       ...        ...
# 566     71.6       2.24
# 567     63.0       3.51
# 568    79.18      15.61
# 569    73.99       1.99
# 570    81.97      11.65
#
# [571 rows x 9 columns]

# %%
#Drop the empty values and clean the table
nan_value = float("NaN")
clean_city_data_df.replace("", nan_value, inplace = True)
clean_city_data_df.dropna(subset = ["Country"], inplace = True)
clean_city_data_df.dropna(subset = ["Cloudiness"], inplace = True)
clean_city_data_df.dropna(subset = ["Date"], inplace = True)
clean_city_data_df.dropna(subset = ["Humidity"], inplace = True)
clean_city_data_df.dropna(subset = ["Lat"], inplace = True)
clean_city_data_df.dropna(subset = ["Lng"], inplace = True)
clean_city_data_df.dropna(subset = ["Max_Temp"], inplace = True)
clean_city_data_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df
# Out:
#           City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0       albany       97.0      US  1595212502.0     94.0    42.6  -73.97
# 1         zeya      100.0      RU  1595212795.0     87.0   53.75  127.27
# 2       vostok      100.0      RU  1595212796.0     30.0   46.49  135.88
# 3    busselton        0.0      AU  1595212625.0     54.0  -33.65  115.33
# 4       castro        0.0      BR  1595212634.0     90.0  -24.79  -50.01
# ..         ...        ...     ...           ...      ...     ...     ...
# 566      pilar       75.0      BR  1595212927.0     94.0    -9.6  -35.96
# 567   zhigansk      100.0      RU  1595212927.0     69.0   66.77  123.37
# 568    bubaque      100.0      GW  1595212927.0     85.0   11.28  -15.83
# 569  ann arbor       59.0      US  1595212774.0     96.0   42.28  -83.74
# 570  maracaibo       88.0      VE  1595212649.0     79.0   10.63  -71.64
#
#     Max_Temp Wind_Speed
# 0      80.01       4.36
# 1      70.38      10.38
# 2      81.81       7.85
# 3       61.0      10.76
# 4      54.81       3.62
# ..       ...        ...
# 566     71.6       2.24
# 567     63.0       3.51
# 568    79.18      15.61
# 569    73.99       1.99
# 570    81.97      11.65
#
# [566 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          566
# Cloudiness    566
# Country       566
# Date          566
# Humidity      566
# Lat           566
# Lng           566
# Max_Temp      566
# Wind_Speed    566
# dtype: int64

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = clean_city_data_df[["Lat", "Lng"]].astype(float)
humidity = clean_city_data_df["Humidity"].astype(float)
humidity
# Out:
# 0      94.0
# 1      87.0
# 2      30.0
# 3      54.0
# 4      90.0
#        ...
# 566    94.0
# 567    69.0
# 568    85.0
# 569    96.0
# 570    79.0
# Name: Humidity, Length: 566, dtype: float64

# %%
#addig heatmap
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
plt.savefig("Figures/Heat_Map.png")

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Create the Ideal vacation = Tempretaure between 60 and 85 F, wind speed lower than 20mph, and cloudiness <3

ideal_vacation_df = clean_city_data_df[clean_city_data_df["Max_Temp"] > "60"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Max_Temp"] < "85"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Wind_Speed"] < "15"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Cloudiness"] == "0.0"]
ideal_vacation_df
# Out:
#                City Cloudiness Country          Date Humidity     Lat  \
# 3         busselton        0.0      AU  1595212625.0     54.0  -33.65
# 23        carnarvon        0.0      AU  1595212712.0     42.0  -24.87
# 61         flinders        0.0      AU  1595212810.0     41.0  -34.58
# 239         ballina        0.0      AU  1595212853.0     37.0  -28.87
# 244       byron bay        0.0      AU  1595212854.0     37.0  -28.65
# 261          lompoc        0.0      US  1595212777.0     72.0   34.64
# 293        celestun        0.0      MX  1595212865.0     76.0   20.87
# 348          tiznit        0.0      MA  1595212842.0     38.0   29.58
# 369       morondava        0.0      MG  1595212883.0     58.0  -20.28
# 379            jalu        0.0      LY  1595212863.0     53.0   29.03
# 401  guerrero negro        0.0      MX  1595212889.0     82.0   27.98
# 419     mitsamiouli        0.0      KM  1595212686.0     67.0  -11.38
# 551        umuarama        0.0      BR  1595212924.0     71.0  -23.77
#
#          Lng Max_Temp Wind_Speed
# 3     115.33     61.0      10.76
# 23    113.63     66.2      14.99
# 61    150.86     64.0      11.01
# 239   153.57     73.0       1.99
# 244   153.62     73.0       1.99
# 261  -120.46     64.4      12.75
# 293    -90.4    81.73      12.06
# 348     -9.5    77.18        1.7
# 369    44.28    65.43      12.15
# 379    21.55    74.05      10.13
# 401  -114.06    69.37      13.24
# 419    43.28     76.1       13.2
# 551   -53.33    65.01      10.22

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
maps_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
hotel_df = ideal_vacation_df.loc[:, ["City", "Country", "Lat", "Lng", "Max_Temp"]]

for index, row in hotel_df.iterrows():
    # pull in needed data
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    params["location"] = f"{lat},{lng}"
    print(f"display the results {index}: {city_name}.")
    response = requests.get(maps_url, params=params).json()
    final_results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Nearby hotel in {city_name} is {final_results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = final_results[0]['name']

    # if there is no hotel available print this
    except (KeyError, IndexError):
        print("Not a hotel... next.")
        
        print("-------End of Search-------")
# Out:
# display the results 3: busselton.
# Nearby hotel in busselton is Restawile Motel.
# display the results 23: carnarvon.
# Nearby hotel in carnarvon is Coral Coast Tourist Park.
# display the results 61: flinders.
# Nearby hotel in flinders is Lakeview Hotel Motel.
# display the results 239: ballina.
# Nearby hotel in ballina is Ramada Hotel & Suites by Wyndham Ballina Byron.
# display the results 244: byron bay.
# Nearby hotel in byron bay is The Park Hotel Motel.
# display the results 261: lompoc.
# Nearby hotel in lompoc is Embassy Suites by Hilton Lompoc Central Coast.
# display the results 293: celestun.
# Nearby hotel in celestun is Eco Hotel Flamingo Playa.
# display the results 348: tiznit.
# Not a hotel... next.
# -------End of Search-------
# display the results 369: morondava.
# Nearby hotel in morondava is Kimony Resort Hotel.
# display the results 379: jalu.
# Nearby hotel in jalu is Jalu Hotel.
# display the results 401: guerrero negro.
# Nearby hotel in guerrero negro is Casa Laguna, Bed & Breakfast.
# display the results 419: mitsamiouli.
# Nearby hotel in mitsamiouli is Moina Lisa.
# display the results 551: umuarama.
# Nearby hotel in umuarama is HOTEL CAIUÁ.

# %%
hotel_df
# Out:
#                City Country     Lat      Lng Max_Temp  \
# 3         busselton      AU  -33.65   115.33     61.0
# 23        carnarvon      AU  -24.87   113.63     66.2
# 61         flinders      AU  -34.58   150.86     64.0
# 239         ballina      AU  -28.87   153.57     73.0
# 244       byron bay      AU  -28.65   153.62     73.0
# 261          lompoc      US   34.64  -120.46     64.4
# 293        celestun      MX   20.87    -90.4    81.73
# 369       morondava      MG  -20.28    44.28    65.43
# 379            jalu      LY   29.03    21.55    74.05
# 401  guerrero negro      MX   27.98  -114.06    69.37
# 419     mitsamiouli      KM  -11.38    43.28     76.1
# 551        umuarama      BR  -23.77   -53.33    65.01
#
#                                          Hotel Name
# 3                                   Restawile Motel
# 23                         Coral Coast Tourist Park
# 61                             Lakeview Hotel Motel
# 239  Ramada Hotel & Suites by Wyndham Ballina Byron
# 244                            The Park Hotel Motel
# 261   Embassy Suites by Hilton Lompoc Central Coast
# 293                        Eco Hotel Flamingo Playa
# 369                             Kimony Resort Hotel
# 379                                      Jalu Hotel
# 401                    Casa Laguna, Bed & Breakfast
# 419                                      Moina Lisa
# 551                                     HOTEL CAIUÁ

# %%
#Replace the emppty values with Nan=N, then clean the data frame from the NaN values
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace = True)
hotel_df.dropna(subset = ["Hotel Name"], inplace = True)
hotel_df
# Out:
#                City Country     Lat      Lng Max_Temp  \
# 3         busselton      AU  -33.65   115.33     61.0
# 23        carnarvon      AU  -24.87   113.63     66.2
# 61         flinders      AU  -34.58   150.86     64.0
# 239         ballina      AU  -28.87   153.57     73.0
# 244       byron bay      AU  -28.65   153.62     73.0
# 261          lompoc      US   34.64  -120.46     64.4
# 293        celestun      MX   20.87    -90.4    81.73
# 369       morondava      MG  -20.28    44.28    65.43
# 379            jalu      LY   29.03    21.55    74.05
# 401  guerrero negro      MX   27.98  -114.06    69.37
# 419     mitsamiouli      KM  -11.38    43.28     76.1
# 551        umuarama      BR  -23.77   -53.33    65.01
#
#                                          Hotel Name
# 3                                   Restawile Motel
# 23                         Coral Coast Tourist Park
# 61                             Lakeview Hotel Motel
# 239  Ramada Hotel & Suites by Wyndham Ballina Byron
# 244                            The Park Hotel Motel
# 261   Embassy Suites by Hilton Lompoc Central Coast
# 293                        Eco Hotel Flamingo Playa
# 369                             Kimony Resort Hotel
# 379                                      Jalu Hotel
# 401                    Casa Laguna, Bed & Breakfast
# 419                                      Moina Lisa
# 551                                     HOTEL CAIUÁ

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
hotel_info
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>Restawile Motel</dd>\n<dt>City</dt><dd>busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Coral Coast Tourist Park</dd>\n<dt>City</dt><dd>carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Lakeview Hotel Motel</dd>\n<dt>City</dt><dd>flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Ramada Hotel & Suites by Wyndham Ballina Byron</dd>\n<dt>City</dt><dd>ballina</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>The Park Hotel Motel</dd>\n<dt>City</dt><dd>byron bay</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Embassy Suites by Hilton Lompoc Central Coast</dd>\n<dt>City</dt><dd>lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Eco Hotel Flamingo Playa</dd>\n<dt>City</dt><dd>celestun</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Kimony Resort Hotel</dd>\n<dt>City</dt><dd>morondava</dd>\n<dt>Country</dt><dd>MG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Jalu Hotel</dd>\n<dt>City</dt><dd>jalu</dd>\n<dt>Country</dt><dd>LY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Casa Laguna, Bed & Breakfast</dd>\n<dt>City</dt><dd>guerrero negro</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Moina Lisa</dd>\n<dt>City</dt><dd>mitsamiouli</dd>\n<dt>Country</dt><dd>KM</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>HOTEL CAIUÁ</dd>\n<dt>City</dt><dd>umuarama</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n']

# %%
hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig = gmaps.figure() 
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-eccb0af680a5> in <module>
# ----> 1 hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       2 fig = gmaps.figure()
#       3 fig.add_layer(heat_layer)
#       4 fig.add_layer(hotel_layer)
#       5 fig
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
