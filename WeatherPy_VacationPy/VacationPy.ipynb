# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
# from config import gkey
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_data_df= pd.read_csv(
    "Resources/clean_cities.csv", dtype="object", encoding="utf-8")

# Visualize
clean_city_data_df
# Out:
#               City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0          qaanaaq       99.0      GL  1595211509.0     75.0   77.48  -69.36
# 1          ushuaia        0.0      AR  1595211509.0     92.0   -54.8   -68.3
# 2         hermanus        7.0      ZA  1595211510.0     93.0  -34.42   19.23
# 3          dunedin      100.0      NZ  1595210959.0     79.0  -45.87   170.5
# 4            pisco       17.0      PE  1595211510.0     82.0   -13.7  -76.22
# ..             ...        ...     ...           ...      ...     ...     ...
# 533    fort nelson       75.0      CA  1595211638.0     44.0   58.81  -122.7
# 534          kieta        6.0      PG  1595211638.0     73.0   -6.22  155.63
# 535  malko tarnovo       91.0      BG  1595211638.0     64.0   41.98   27.53
# 536          enshi       96.0      CN  1595211638.0     76.0    30.3  109.48
# 537     las palmas        0.0      ES  1595211638.0     61.0   28.42  -14.01
#
#     Max_Temp Wind_Speed
# 0      46.04       0.76
# 1       26.6       5.82
# 2       54.0       1.99
# 3       48.0       1.99
# 4       61.0       8.05
# ..       ...        ...
# 533     75.2       3.36
# 534    83.95       8.25
# 535     71.6        4.7
# 536    78.82        1.7
# 537     78.8      13.87
#
# [538 rows x 9 columns]

# %%
#Drop the empty values and clean the table
nan_value = float("NaN")
clean_city_data_df.replace("", nan_value, inplace = True)
clean_city_data_df.dropna(subset = ["Country"], inplace = True)
clean_city_data_df.dropna(subset = ["Cloudiness"], inplace = True)
clean_city_data_df.dropna(subset = ["Date"], inplace = True)
clean_city_data_df.dropna(subset = ["Humidity"], inplace = True)
clean_city_data_df.dropna(subset = ["Lat"], inplace = True)
clean_city_data_df.dropna(subset = ["Lng"], inplace = True)
clean_city_data_df.dropna(subset = ["Max_Temp"], inplace = True)
clean_city_data_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df
# Out:
#               City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0          qaanaaq       99.0      GL  1595211509.0     75.0   77.48  -69.36
# 1          ushuaia        0.0      AR  1595211509.0     92.0   -54.8   -68.3
# 2         hermanus        7.0      ZA  1595211510.0     93.0  -34.42   19.23
# 3          dunedin      100.0      NZ  1595210959.0     79.0  -45.87   170.5
# 4            pisco       17.0      PE  1595211510.0     82.0   -13.7  -76.22
# ..             ...        ...     ...           ...      ...     ...     ...
# 533    fort nelson       75.0      CA  1595211638.0     44.0   58.81  -122.7
# 534          kieta        6.0      PG  1595211638.0     73.0   -6.22  155.63
# 535  malko tarnovo       91.0      BG  1595211638.0     64.0   41.98   27.53
# 536          enshi       96.0      CN  1595211638.0     76.0    30.3  109.48
# 537     las palmas        0.0      ES  1595211638.0     61.0   28.42  -14.01
#
#     Max_Temp Wind_Speed
# 0      46.04       0.76
# 1       26.6       5.82
# 2       54.0       1.99
# 3       48.0       1.99
# 4       61.0       8.05
# ..       ...        ...
# 533     75.2       3.36
# 534    83.95       8.25
# 535     71.6        4.7
# 536    78.82        1.7
# 537     78.8      13.87
#
# [534 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          534
# Cloudiness    534
# Country       534
# Date          534
# Humidity      534
# Lat           534
# Lng           534
# Max_Temp      534
# Wind_Speed    534
# dtype: int64

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = clean_city_data_df[["Lat", "Lng"]].astype(float)
humidity = clean_city_data_df["Humidity"].astype(float)
humidity
# Out:
# 0      75.0
# 1      92.0
# 2      93.0
# 3      79.0
# 4      82.0
#        ...
# 533    44.0
# 534    73.0
# 535    64.0
# 536    76.0
# 537    61.0
# Name: Humidity, Length: 534, dtype: float64

# %%
#addig heatmap
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
plt.savefig("Figures/Heat_Map.png")

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Create the Ideal vacation = Tempretaure between 60 and 85 F, wind speed lower than 20mph, and cloudiness <3

ideal_vacation_df = clean_city_data_df[clean_city_data_df["Max_Temp"] > "60"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Max_Temp"] < "85"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Wind_Speed"] < "15"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Cloudiness"] == "0.0"]
ideal_vacation_df
# Out:
#                     City Cloudiness Country          Date Humidity     Lat  \
# 21             busselton        0.0      AU  1595211431.0     57.0  -33.65
# 34              taormina        0.0      IT  1595211517.0     78.0   37.85
# 44             kungurtug        0.0      RU  1595211519.0     29.0    50.6
# 45                weihai        0.0      CN  1595211519.0     81.0    37.5
# 74                 salto        0.0      UY  1595211367.0     62.0  -31.38
# 106                kindu        0.0      CD  1595211363.0     62.0   -2.95
# 118               tiznit        0.0      MA  1595211538.0     33.0   29.58
# 132             flinders        0.0      AU  1595211542.0     41.0  -34.58
# 134  santiago del estero        0.0      AR  1595210956.0     71.0   -27.8
# 194          gondanglegi        0.0      ID  1595211555.0     69.0   -7.75
# 250            carnarvon        0.0      AU  1595211460.0     42.0  -24.87
# 259               lompoc        0.0      US  1595211469.0     72.0   34.64
# 280                 asfi        0.0      MA  1595211574.0     80.0    32.3
# 283            sao borja        0.0      BR  1595211575.0     76.0  -28.66
# 319              ladario        0.0      BR  1595211583.0     48.0   -19.0
# 348            road town        0.0      VG  1595211589.0     81.0   18.42
# 349                aktau        0.0      KZ  1595211589.0     38.0   43.65
# 370             carauari        0.0      BR  1595211594.0     94.0   -4.88
# 383             zyryanka        0.0      RU  1595211596.0     37.0   65.75
# 394           maningrida        0.0      AU  1595211599.0     46.0  -12.07
# 426            beni suef        0.0      EG  1595211608.0     75.0   29.07
# 512             la union        0.0      PE  1595211632.0     75.0    -5.4
# 537           las palmas        0.0      ES  1595211638.0     61.0   28.42
#
#          Lng Max_Temp Wind_Speed
# 21    115.33    60.01      10.07
# 34     15.29    73.99       1.01
# 44     97.52    68.67       0.78
# 45    122.11    73.56      11.92
# 74    -57.97    73.99       14.0
# 106    25.95    66.27       1.21
# 118     -9.5    79.63       0.87
# 132   150.86     64.0       14.0
# 134   -64.26    71.01       1.54
# 194   112.01    82.24      12.88
# 250   113.63     66.2      14.99
# 259  -120.46     64.4      13.87
# 280    -9.24     71.1      11.48
# 283    -56.0    67.14      10.98
# 319    -57.6    72.59       1.52
# 348   -64.62    82.99       14.0
# 349     51.2     77.0      11.18
# 370    -66.9    73.62       0.83
# 383   150.85    78.21      14.76
# 394   134.27     79.9       11.1
# 426     31.1    72.86      12.44
# 512   -80.75    64.44      13.78
# 537   -14.01     78.8      13.87

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
maps_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
hotel_df = ideal_vacation_df.loc[:, ["City", "Country", "Lat", "Lng", "Max_Temp"]]

for index, row in hotel_df.iterrows():
    # pull in needed data
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    params["location"] = f"{lat},{lng}"
    print(f"display the results {index}: {city_name}.")
    response = requests.get(maps_url, params=params).json()
    final_results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Nearby hotel in {city_name} is {final_results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = final_results[0]['name']

    # if there is no hotel available print this
    except (KeyError, IndexError):
        print("Not a hotel... next.")
        
        print("-------End of Search-------")
# Out:
# display the results 21: busselton.
# Nearby hotel in busselton is Esplanade Hotel.
# display the results 34: taormina.
# Nearby hotel in taormina is Belmond Grand Hotel Timeo.
# display the results 44: kungurtug.
# Not a hotel... next.
# -------End of Search-------
# display the results 45: weihai.
# Nearby hotel in weihai is Weihai Golden Bay Hotel.
# display the results 74: salto.
# Nearby hotel in salto is Salto Hotel & Casino.
# display the results 106: kindu.
# Nearby hotel in kindu is Valencia City Hotel.
# display the results 118: tiznit.
# Not a hotel... next.
# -------End of Search-------
# display the results 132: flinders.
# Nearby hotel in flinders is Lakeview Hotel Motel.
# display the results 134: santiago del estero.
# Nearby hotel in santiago del estero is Hotel Coventry.
# display the results 194: gondanglegi.
# Nearby hotel in gondanglegi is Adisurya Hotel.
# display the results 250: carnarvon.
# Nearby hotel in carnarvon is Hospitality Carnarvon.
# display the results 259: lompoc.
# Nearby hotel in lompoc is Embassy Suites by Hilton Lompoc Central Coast.
# display the results 280: asfi.
# Nearby hotel in asfi is RIAD LE CHEVAL BLANC - HÔTEL.
# display the results 283: sao borja.
# Nearby hotel in sao borja is Hotel Obino São Borja.
# display the results 319: ladario.
# Nearby hotel in ladario is Hotel Portal do Pantanal.
# display the results 348: road town.
# Nearby hotel in road town is Sea View Hotel.
# display the results 349: aktau.
# Nearby hotel in aktau is Caspian Riviera Grand Palace Hotel.
# display the results 370: carauari.
# Nearby hotel in carauari is Tatiana's Hotel.
# display the results 383: zyryanka.
# Not a hotel... next.
# -------End of Search-------
# display the results 394: maningrida.
# Nearby hotel in maningrida is Dhukurrdji Lodge.
# display the results 426: beni suef.
# Nearby hotel in beni suef is Tulip Inn Hotel.
# display the results 512: la union.
# Not a hotel... next.
# -------End of Search-------
# display the results 537: las palmas.
# Nearby hotel in las palmas is Hote Rural Era de La Corte.

# %%
hotel_df
# Out:
#                     City Country     Lat      Lng Max_Temp  \
# 21             busselton      AU  -33.65   115.33    60.01
# 34              taormina      IT   37.85    15.29    73.99
# 44             kungurtug      RU    50.6    97.52    68.67
# 45                weihai      CN    37.5   122.11    73.56
# 74                 salto      UY  -31.38   -57.97    73.99
# 106                kindu      CD   -2.95    25.95    66.27
# 118               tiznit      MA   29.58     -9.5    79.63
# 132             flinders      AU  -34.58   150.86     64.0
# 134  santiago del estero      AR   -27.8   -64.26    71.01
# 194          gondanglegi      ID   -7.75   112.01    82.24
# 250            carnarvon      AU  -24.87   113.63     66.2
# 259               lompoc      US   34.64  -120.46     64.4
# 280                 asfi      MA    32.3    -9.24     71.1
# 283            sao borja      BR  -28.66    -56.0    67.14
# 319              ladario      BR   -19.0    -57.6    72.59
# 348            road town      VG   18.42   -64.62    82.99
# 349                aktau      KZ   43.65     51.2     77.0
# 370             carauari      BR   -4.88    -66.9    73.62
# 383             zyryanka      RU   65.75   150.85    78.21
# 394           maningrida      AU  -12.07   134.27     79.9
# 426            beni suef      EG   29.07     31.1    72.86
# 512             la union      PE    -5.4   -80.75    64.44
# 537           las palmas      ES   28.42   -14.01     78.8
#
#                                         Hotel Name
# 21                                 Esplanade Hotel
# 34                       Belmond Grand Hotel Timeo
# 44                                             NaN
# 45                         Weihai Golden Bay Hotel
# 74                            Salto Hotel & Casino
# 106                            Valencia City Hotel
# 118                                            NaN
# 132                           Lakeview Hotel Motel
# 134                                 Hotel Coventry
# 194                                 Adisurya Hotel
# 250                          Hospitality Carnarvon
# 259  Embassy Suites by Hilton Lompoc Central Coast
# 280                   RIAD LE CHEVAL BLANC - HÔTEL
# 283                          Hotel Obino São Borja
# 319                       Hotel Portal do Pantanal
# 348                                 Sea View Hotel
# 349             Caspian Riviera Grand Palace Hotel
# 370                                Tatiana's Hotel
# 383                                            NaN
# 394                               Dhukurrdji Lodge
# 426                                Tulip Inn Hotel
# 512                                            NaN
# 537                     Hote Rural Era de La Corte

# %%
#Replace the emppty values with Nan=N, then clean the data frame from the NaN values
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace = True)
hotel_df.dropna(subset = ["Hotel Name"], inplace = True)
hotel_df
# Out:
#                     City Country     Lat      Lng Max_Temp  \
# 21             busselton      AU  -33.65   115.33    60.01
# 34              taormina      IT   37.85    15.29    73.99
# 45                weihai      CN    37.5   122.11    73.56
# 74                 salto      UY  -31.38   -57.97    73.99
# 106                kindu      CD   -2.95    25.95    66.27
# 132             flinders      AU  -34.58   150.86     64.0
# 134  santiago del estero      AR   -27.8   -64.26    71.01
# 194          gondanglegi      ID   -7.75   112.01    82.24
# 250            carnarvon      AU  -24.87   113.63     66.2
# 259               lompoc      US   34.64  -120.46     64.4
# 280                 asfi      MA    32.3    -9.24     71.1
# 283            sao borja      BR  -28.66    -56.0    67.14
# 319              ladario      BR   -19.0    -57.6    72.59
# 348            road town      VG   18.42   -64.62    82.99
# 349                aktau      KZ   43.65     51.2     77.0
# 370             carauari      BR   -4.88    -66.9    73.62
# 394           maningrida      AU  -12.07   134.27     79.9
# 426            beni suef      EG   29.07     31.1    72.86
# 537           las palmas      ES   28.42   -14.01     78.8
#
#                                         Hotel Name
# 21                                 Esplanade Hotel
# 34                       Belmond Grand Hotel Timeo
# 45                         Weihai Golden Bay Hotel
# 74                            Salto Hotel & Casino
# 106                            Valencia City Hotel
# 132                           Lakeview Hotel Motel
# 134                                 Hotel Coventry
# 194                                 Adisurya Hotel
# 250                          Hospitality Carnarvon
# 259  Embassy Suites by Hilton Lompoc Central Coast
# 280                   RIAD LE CHEVAL BLANC - HÔTEL
# 283                          Hotel Obino São Borja
# 319                       Hotel Portal do Pantanal
# 348                                 Sea View Hotel
# 349             Caspian Riviera Grand Palace Hotel
# 370                                Tatiana's Hotel
# 394                               Dhukurrdji Lodge
# 426                                Tulip Inn Hotel
# 537                     Hote Rural Era de La Corte

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
hotel_info
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>Esplanade Hotel</dd>\n<dt>City</dt><dd>busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Belmond Grand Hotel Timeo</dd>\n<dt>City</dt><dd>taormina</dd>\n<dt>Country</dt><dd>IT</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Weihai Golden Bay Hotel</dd>\n<dt>City</dt><dd>weihai</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Salto Hotel & Casino</dd>\n<dt>City</dt><dd>salto</dd>\n<dt>Country</dt><dd>UY</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Valencia City Hotel</dd>\n<dt>City</dt><dd>kindu</dd>\n<dt>Country</dt><dd>CD</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Lakeview Hotel Motel</dd>\n<dt>City</dt><dd>flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel Coventry</dd>\n<dt>City</dt><dd>santiago del estero</dd>\n<dt>Country</dt><dd>AR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Adisurya Hotel</dd>\n<dt>City</dt><dd>gondanglegi</dd>\n<dt>Country</dt><dd>ID</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Embassy Suites by Hilton Lompoc Central Coast</dd>\n<dt>City</dt><dd>lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>RIAD LE CHEVAL BLANC - HÔTEL</dd>\n<dt>City</dt><dd>asfi</dd>\n<dt>Country</dt><dd>MA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel Obino São Borja</dd>\n<dt>City</dt><dd>sao borja</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel Portal do Pantanal</dd>\n<dt>City</dt><dd>ladario</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Sea View Hotel</dd>\n<dt>City</dt><dd>road town</dd>\n<dt>Country</dt><dd>VG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Caspian Riviera Grand Palace Hotel</dd>\n<dt>City</dt><dd>aktau</dd>\n<dt>Country</dt><dd>KZ</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Name</dt><dd>Tatiana's Hotel</dd>\n<dt>City</dt><dd>carauari</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Name</dt><dd>Dhukurrdji Lodge</dd>\n<dt>City</dt><dd>maningrida</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Tulip Inn Hotel</dd>\n<dt>City</dt><dd>beni suef</dd>\n<dt>Country</dt><dd>EG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hote Rural Era de La Corte</dd>\n<dt>City</dt><dd>las palmas</dd>\n<dt>Country</dt><dd>ES</dd>\n</dl>\n']

# %%
hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig = gmaps.figure() 
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-eccb0af680a5> in <module>
# ----> 1 hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       2 fig = gmaps.figure()
#       3 fig.add_layer(heat_layer)
#       4 fig.add_layer(hotel_layer)
#       5 fig
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
