# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
# from config import gkey
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_data_df= pd.read_csv(
    "Resources/clean_cities.csv", dtype="object", encoding="utf-8")

# Visualize
clean_city_data_df
# Out:
#                City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0        butaritari        0.0      KI  1595208768.0     77.0    3.07  172.79
# 1    ribeira grande       55.0      PT  1595208764.0     77.0   38.52   -28.7
# 2            dikson       99.0      RU  1595208773.0     96.0   73.51   80.55
# 3          hokitika      100.0      NZ  1595209285.0     74.0  -42.72  170.97
# 4          belmonte       40.0      BR  1595208807.0     94.0  -15.86  -38.88
# ..              ...        ...     ...           ...      ...     ...     ...
# 576         yajalon       91.0      MX  1595209410.0     98.0   17.23  -92.33
# 577     clyde river        1.0      CA  1595209410.0     75.0   70.47  -68.59
# 578       norrtalje      100.0      SE  1595209411.0     67.0   59.76    18.7
# 579        bougouni       22.0      ML  1595209411.0     90.0   11.42   -7.48
# 580        ajdabiya        0.0      LY  1595208823.0     73.0   30.76   20.23
#
#     Max_Temp Wind_Speed
# 0      83.61      15.28
# 1      69.06       2.77
# 2      41.45      10.25
# 3      56.89       6.44
# 4       69.8       5.82
# ..       ...        ...
# 576    67.21       1.86
# 577     44.6       6.93
# 578     66.0        4.0
# 579    73.63       3.96
# 580    70.68       8.39
#
# [581 rows x 9 columns]

# %%
#Drop the empty values and clean the table
nan_value = float("NaN")
clean_city_data_df.replace("", nan_value, inplace = True)
clean_city_data_df.dropna(subset = ["Country"], inplace = True)
clean_city_data_df.dropna(subset = ["Cloudiness"], inplace = True)
clean_city_data_df.dropna(subset = ["Date"], inplace = True)
clean_city_data_df.dropna(subset = ["Humidity"], inplace = True)
clean_city_data_df.dropna(subset = ["Lat"], inplace = True)
clean_city_data_df.dropna(subset = ["Lng"], inplace = True)
clean_city_data_df.dropna(subset = ["Max_Temp"], inplace = True)
clean_city_data_df.dropna(subset = ["Wind_Speed"], inplace = True)
clean_city_data_df
# Out:
#                City Cloudiness Country          Date Humidity     Lat     Lng  \
# 0        butaritari        0.0      KI  1595208768.0     77.0    3.07  172.79
# 1    ribeira grande       55.0      PT  1595208764.0     77.0   38.52   -28.7
# 2            dikson       99.0      RU  1595208773.0     96.0   73.51   80.55
# 3          hokitika      100.0      NZ  1595209285.0     74.0  -42.72  170.97
# 4          belmonte       40.0      BR  1595208807.0     94.0  -15.86  -38.88
# ..              ...        ...     ...           ...      ...     ...     ...
# 576         yajalon       91.0      MX  1595209410.0     98.0   17.23  -92.33
# 577     clyde river        1.0      CA  1595209410.0     75.0   70.47  -68.59
# 578       norrtalje      100.0      SE  1595209411.0     67.0   59.76    18.7
# 579        bougouni       22.0      ML  1595209411.0     90.0   11.42   -7.48
# 580        ajdabiya        0.0      LY  1595208823.0     73.0   30.76   20.23
#
#     Max_Temp Wind_Speed
# 0      83.61      15.28
# 1      69.06       2.77
# 2      41.45      10.25
# 3      56.89       6.44
# 4       69.8       5.82
# ..       ...        ...
# 576    67.21       1.86
# 577     44.6       6.93
# 578     66.0        4.0
# 579    73.63       3.96
# 580    70.68       8.39
#
# [577 rows x 9 columns]

# %%
clean_city_data_df.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max_Temp      577
# Wind_Speed    577
# dtype: int64

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = clean_city_data_df[["Lat", "Lng"]].astype(float)
humidity = clean_city_data_df["Humidity"].astype(float)
humidity
# Out:
# 0      77.0
# 1      77.0
# 2      96.0
# 3      74.0
# 4      94.0
#        ...
# 576    98.0
# 577    75.0
# 578    67.0
# 579    90.0
# 580    73.0
# Name: Humidity, Length: 577, dtype: float64

# %%
#addig heatmap
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights = humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)
fig.add_layer(heat_layer)
fig
plt.savefig("Figures/Heat_Map.png")

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Create the Ideal vacation = Tempretaure between 60 and 85 F, wind speed lower than 20mph, and cloudiness <3

ideal_vacation_df = clean_city_data_df[clean_city_data_df["Max_Temp"] > "60"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Max_Temp"] < "85"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Wind_Speed"] < "15"]
ideal_vacation_df = ideal_vacation_df[ideal_vacation_df["Cloudiness"] == "0.0"]
ideal_vacation_df
# Out:
#                       City Cloudiness Country          Date Humidity     Lat  \
# 90                     gat        0.0      IL  1595209083.0     68.0   31.61
# 137                 lompoc        0.0      US  1595208699.0     72.0   34.64
# 154               la union        0.0      PE  1595209318.0     75.0    -5.4
# 158               celestun        0.0      MX  1595209319.0     76.0   20.87
# 187                  nyrob        0.0      RU  1595209326.0     68.0   60.73
# 192                chengde        0.0      CN  1595209327.0     40.0   40.97
# 240                   asfi        0.0      MA  1595209338.0     80.0    32.3
# 267               imbituba        0.0      BR  1595209310.0    100.0  -28.24
# 272               flinders        0.0      AU  1595209345.0     42.0  -34.58
# 274                lusambo        0.0      CD  1595209345.0     49.0   -4.97
# 291                angoche        0.0      MZ  1595209349.0     79.0  -16.23
# 342                birjand        0.0      IR  1595209360.0     15.0   32.87
# 423                  kindu        0.0      CD  1595208794.0     62.0   -2.95
# 459  los llanos de aridane        0.0      ES  1595208810.0     83.0   28.66
# 479                   emba        0.0      KZ  1595208793.0     44.0   48.83
# 481               bilibino        0.0      RU  1595208801.0     27.0   68.05
# 495         savannah bight        0.0      HN  1595209393.0     77.0   16.45
# 557              morondava        0.0      MG  1595208841.0     59.0  -20.28
# 570                tortosa        0.0      ES  1595209409.0     89.0   40.81
#
#          Lng Max_Temp Wind_Speed
# 90     34.76    75.99       1.92
# 137  -120.46     66.0      13.87
# 154   -80.75    64.44      13.78
# 158    -90.4    82.17      11.61
# 187    56.72    63.61      10.89
# 192   117.94    80.89       1.59
# 240    -9.24     71.1      11.48
# 267   -48.67     64.4      12.75
# 272   150.86    62.01      11.99
# 274    23.45    64.83       1.99
# 291    39.91    70.29      10.47
# 342    59.22     73.4      11.41
# 423    25.95    66.27       1.21
# 459   -17.92    75.99      14.99
# 479    58.14    75.74      12.03
# 481   166.44    72.18       1.34
# 495   -85.85    83.95      14.67
# 557    44.28    66.34      13.51
# 570     0.52    73.99       1.99

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
maps_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

# %%
hotel_df = ideal_vacation_df.loc[:, ["City", "Country", "Lat", "Lng", "Max_Temp"]]

for index, row in hotel_df.iterrows():
    # pull in needed data
    lat = row["Lat"]
    lng = row["Lng"]
    city_name = row["City"]
    params["location"] = f"{lat},{lng}"
    print(f"display the results {index}: {city_name}.")
    response = requests.get(maps_url, params=params).json()
    final_results = response['results']
    
    # save the hotel name to dataframe
    try:
        print(f"Nearby hotel in {city_name} is {final_results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = final_results[0]['name']

    # if there is no hotel available print this
    except (KeyError, IndexError):
        print("Not a hotel... next.")
        
        print("-------End of Search-------")
# Out:
# display the results 90: gat.
# Nearby hotel in gat is Desert Gat.
# display the results 137: lompoc.
# Nearby hotel in lompoc is Embassy Suites by Hilton Lompoc Central Coast.
# display the results 154: la union.
# Not a hotel... next.
# -------End of Search-------
# display the results 158: celestun.
# Nearby hotel in celestun is Eco Hotel Flamingo Playa.
# display the results 187: nyrob.
# Nearby hotel in nyrob is Gostinitsa.
# display the results 192: chengde.
# Nearby hotel in chengde is Yunshan Hotel.
# display the results 240: asfi.
# Nearby hotel in asfi is Hôtel Farah Safi.
# display the results 267: imbituba.
# Nearby hotel in imbituba is Praia Hotel Imbituba.
# display the results 272: flinders.
# Nearby hotel in flinders is Lakeview Hotel Motel.
# display the results 274: lusambo.
# Not a hotel... next.
# -------End of Search-------
# display the results 291: angoche.
# Nearby hotel in angoche is Guest House HESADA.
# display the results 342: birjand.
# Nearby hotel in birjand is Sepehr Hotel.
# display the results 423: kindu.
# Nearby hotel in kindu is Valencia City Hotel.
# display the results 459: los llanos de aridane.
# Nearby hotel in los llanos de aridane is Hotel Hacienda de Abajo.
# display the results 479: emba.
# Not a hotel... next.
# -------End of Search-------
# display the results 481: bilibino.
# Nearby hotel in bilibino is Profilaktoriy Baes.
# display the results 495: savannah bight.
# Nearby hotel in savannah bight is Villa on Dunbar Rock.
# display the results 557: morondava.
# Nearby hotel in morondava is Kimony Resort Hotel.
# display the results 570: tortosa.
# Nearby hotel in tortosa is Parador de Tortosa.

# %%
hotel_df
# Out:
#                       City Country     Lat      Lng Max_Temp  \
# 90                     gat      IL   31.61    34.76    75.99
# 137                 lompoc      US   34.64  -120.46     66.0
# 154               la union      PE    -5.4   -80.75    64.44
# 158               celestun      MX   20.87    -90.4    82.17
# 187                  nyrob      RU   60.73    56.72    63.61
# 192                chengde      CN   40.97   117.94    80.89
# 240                   asfi      MA    32.3    -9.24     71.1
# 267               imbituba      BR  -28.24   -48.67     64.4
# 272               flinders      AU  -34.58   150.86    62.01
# 274                lusambo      CD   -4.97    23.45    64.83
# 291                angoche      MZ  -16.23    39.91    70.29
# 342                birjand      IR   32.87    59.22     73.4
# 423                  kindu      CD   -2.95    25.95    66.27
# 459  los llanos de aridane      ES   28.66   -17.92    75.99
# 479                   emba      KZ   48.83    58.14    75.74
# 481               bilibino      RU   68.05   166.44    72.18
# 495         savannah bight      HN   16.45   -85.85    83.95
# 557              morondava      MG  -20.28    44.28    66.34
# 570                tortosa      ES   40.81     0.52    73.99
#
#                                         Hotel Name
# 90                                      Desert Gat
# 137  Embassy Suites by Hilton Lompoc Central Coast
# 154                                            NaN
# 158                       Eco Hotel Flamingo Playa
# 187                                     Gostinitsa
# 192                                  Yunshan Hotel
# 240                               Hôtel Farah Safi
# 267                           Praia Hotel Imbituba
# 272                           Lakeview Hotel Motel
# 274                                            NaN
# 291                             Guest House HESADA
# 342                                   Sepehr Hotel
# 423                            Valencia City Hotel
# 459                        Hotel Hacienda de Abajo
# 479                                            NaN
# 481                             Profilaktoriy Baes
# 495                           Villa on Dunbar Rock
# 557                            Kimony Resort Hotel
# 570                             Parador de Tortosa

# %%
#Replace the emppty values with Nan=N, then clean the data frame from the NaN values
nan_value = float("NaN")
hotel_df.replace("", nan_value, inplace = True)
hotel_df.dropna(subset = ["Hotel Name"], inplace = True)
hotel_df
# Out:
#                       City Country     Lat      Lng Max_Temp  \
# 90                     gat      IL   31.61    34.76    75.99
# 137                 lompoc      US   34.64  -120.46     66.0
# 158               celestun      MX   20.87    -90.4    82.17
# 187                  nyrob      RU   60.73    56.72    63.61
# 192                chengde      CN   40.97   117.94    80.89
# 240                   asfi      MA    32.3    -9.24     71.1
# 267               imbituba      BR  -28.24   -48.67     64.4
# 272               flinders      AU  -34.58   150.86    62.01
# 291                angoche      MZ  -16.23    39.91    70.29
# 342                birjand      IR   32.87    59.22     73.4
# 423                  kindu      CD   -2.95    25.95    66.27
# 459  los llanos de aridane      ES   28.66   -17.92    75.99
# 481               bilibino      RU   68.05   166.44    72.18
# 495         savannah bight      HN   16.45   -85.85    83.95
# 557              morondava      MG  -20.28    44.28    66.34
# 570                tortosa      ES   40.81     0.52    73.99
#
#                                         Hotel Name
# 90                                      Desert Gat
# 137  Embassy Suites by Hilton Lompoc Central Coast
# 158                       Eco Hotel Flamingo Playa
# 187                                     Gostinitsa
# 192                                  Yunshan Hotel
# 240                               Hôtel Farah Safi
# 267                           Praia Hotel Imbituba
# 272                           Lakeview Hotel Motel
# 291                             Guest House HESADA
# 342                                   Sepehr Hotel
# 423                            Valencia City Hotel
# 459                        Hotel Hacienda de Abajo
# 481                             Profilaktoriy Baes
# 495                           Villa on Dunbar Rock
# 557                            Kimony Resort Hotel
# 570                             Parador de Tortosa

# %%
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]
hotel_info
# Out:
# ['\n<dl>\n<dt>Name</dt><dd>Desert Gat</dd>\n<dt>City</dt><dd>gat</dd>\n<dt>Country</dt><dd>IL</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Embassy Suites by Hilton Lompoc Central Coast</dd>\n<dt>City</dt><dd>lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Eco Hotel Flamingo Playa</dd>\n<dt>City</dt><dd>celestun</dd>\n<dt>Country</dt><dd>MX</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Gostinitsa</dd>\n<dt>City</dt><dd>nyrob</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Yunshan Hotel</dd>\n<dt>City</dt><dd>chengde</dd>\n<dt>Country</dt><dd>CN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hôtel Farah Safi</dd>\n<dt>City</dt><dd>asfi</dd>\n<dt>Country</dt><dd>MA</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Praia Hotel Imbituba</dd>\n<dt>City</dt><dd>imbituba</dd>\n<dt>Country</dt><dd>BR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Lakeview Hotel Motel</dd>\n<dt>City</dt><dd>flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Guest House HESADA</dd>\n<dt>City</dt><dd>angoche</dd>\n<dt>Country</dt><dd>MZ</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Sepehr Hotel</dd>\n<dt>City</dt><dd>birjand</dd>\n<dt>Country</dt><dd>IR</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Valencia City Hotel</dd>\n<dt>City</dt><dd>kindu</dd>\n<dt>Country</dt><dd>CD</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Hotel Hacienda de Abajo</dd>\n<dt>City</dt><dd>los llanos de aridane</dd>\n<dt>Country</dt><dd>ES</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Profilaktoriy Baes</dd>\n<dt>City</dt><dd>bilibino</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Villa on Dunbar Rock</dd>\n<dt>City</dt><dd>savannah bight</dd>\n<dt>Country</dt><dd>HN</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Kimony Resort Hotel</dd>\n<dt>City</dt><dd>morondava</dd>\n<dt>Country</dt><dd>MG</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Name</dt><dd>Parador de Tortosa</dd>\n<dt>City</dt><dd>tortosa</dd>\n<dt>Country</dt><dd>ES</dd>\n</dl>\n']

# %%
hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig = gmaps.figure() 
fig.add_layer(heat_layer)
fig.add_layer(hotel_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-eccb0af680a5> in <module>
# ----> 1 hotel_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)
#       2 fig = gmaps.figure()
#       3 fig.add_layer(heat_layer)
#       4 fig.add_layer(hotel_layer)
#       5 fig
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in marker_layer(locations, hover_text, label, info_box_content, display_info_box)
#     554         locations, hover_text, label, info_box_content, display_info_box)
#     555     markers = [Marker(**option) for option in marker_options]
# --> 556     return Markers(markers=markers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
# -> 1000                     super_kwargs[key] = value
#    1001         try:
#    1002             super(HasTraits, self).__init__(*super_args, **super_kwargs)
#
# ~/opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in hold_trait_notifications(self)
#    1129                 for changes in cache.values():
#    1130                     for change in changes:
# -> 1131                         self.notify_change(change)
#    1132
#    1133     def _notify_trait(self, name, old_value, new_value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in notify_change(self, change)
#     604                 # Send new state to front-end
#     605                 self.send_state(key=name)
# --> 606         super(Widget, self).notify_change(change)
#     607
#     608     def __repr__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in notify_change(self, change)
#    1174                 c = getattr(self, c.name)
#    1175
# -> 1176             c(change)
#    1177
#    1178     def _add_notifiers(self, handler, name, type):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/marker.py in _calc_bounds(self, change)
#     232             latitudes = [location[0] for location in locations]
#     233             longitudes = [location[1] for location in locations]
# --> 234             min_latitude, max_latitude = bounds.latitude_bounds(latitudes)
#     235             min_longitude, max_longitude = bounds.longitude_bounds(longitudes)
#     236             self.data_bounds = [
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/bounds.py in latitude_bounds(latitudes)
#      13     Estimate latitude bound with 2*sample standard deviation
#      14     """
# ---> 15     if max(latitudes) - min(latitudes) < 2.0*EPSILON:
#      16         lower_bound = latitudes[0] - EPSILON
#      17         upper_bound = latitudes[0] + EPSILON
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
