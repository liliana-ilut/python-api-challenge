# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime as dt  

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# cities
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 0
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

print(f"Beginning Data Retrieval")
print(f"------------------------------")
for city in cities:
        url = (f'https://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}')
#         print(url)
        weather_response = requests.get(url)
        weather_json = weather_response.json()
#         print(weather_json)
        try: 
            Cloudiness.append(weather_json['clouds']["all"])
            Country.append(weather_json['sys']["country"])
            Date.append(weather_json["dt"])
            Humidity.append(weather_json["main"]['humidity'])
            Lat.append(weather_json["coord"]['lat'])
            Lng.append(weather_json["coord"]['lon'])
            Max_Temp.append(weather_json["main"]['temp_max'])
            Wind_Speed.append(weather_json["wind"]['speed'])
            print( "Requesting " , count,"......" ,city)
            count = count + 1
            
        except KeyError:
        
            Cloudiness.append("")
            Country.append("")
            Date.append("")
            Humidity.append("")
            Lat.append("")
            Lng.append("")
            Max_Temp.append("")
            Wind_Speed.append("")
            print("Requesting " , count,"......" ,city, ".....Error, try again...")
            count = count + 1
# print(Cloudiness)
#             pass
# Out:
# Beginning Data Retrieval
# ------------------------------
# Requesting  0 ...... vaitupu .....Error, try again...
# Requesting  1 ...... bograd
# Requesting  2 ...... butaritari
# Requesting  3 ...... pisco
# Requesting  4 ...... fort nelson
# Requesting  5 ...... avarua
# Requesting  6 ...... bredasdorp
# Requesting  7 ...... yumen
# Requesting  8 ...... gaoual
# Requesting  9 ...... temir
# Requesting  10 ...... milton
# Requesting  11 ...... cayenne
# Requesting  12 ...... trat
# Requesting  13 ...... thompson
# Requesting  14 ...... tuktoyaktuk
# Requesting  15 ...... lodwar
# Requesting  16 ...... bimbo
# Requesting  17 ...... port-gentil
# Requesting  18 ...... tsihombe .....Error, try again...
# Requesting  19 ...... mataura
# Requesting  20 ...... waingapu
# Requesting  21 ...... atuona
# Requesting  22 ...... christchurch
# Requesting  23 ...... san patricio
# Requesting  24 ...... yellowknife
# Requesting  25 ...... san quintin
# Requesting  26 ...... shakhrinau .....Error, try again...
# Requesting  27 ...... saskylakh
# Requesting  28 ...... vaini
# Requesting  29 ...... mar del plata
# Requesting  30 ...... siauliai
# Requesting  31 ...... esna
# Requesting  32 ...... shupiyan
# Requesting  33 ...... dwarka
# Requesting  34 ...... bluff
# Requesting  35 ...... sorland
# Requesting  36 ...... rikitea
# Requesting  37 ...... kapuskasing
# Requesting  38 ...... alyangula
# Requesting  39 ...... ambilobe
# Requesting  40 ...... talara
# Requesting  41 ...... aurillac
# Requesting  42 ...... albany
# Requesting  43 ...... ushuaia
# Requesting  44 ...... kuche .....Error, try again...
# Requesting  45 ...... makakilo city
# Requesting  46 ...... namibe
# Requesting  47 ...... port alfred
# Requesting  48 ...... marcona .....Error, try again...
# Requesting  49 ...... teya
# Requesting  50 ...... hobart
# Requesting  51 ...... new norfolk
# Requesting  52 ...... sao filipe
# Requesting  582 ...... bangassou
# Requesting  583 ...... roanoke rapids
# Requesting  584 ...... karpuninskiy .....Error, try again...
# Requesting  585 ...... maralal
# Requesting  586 ...... yeppoon
# Requesting  587 ...... seoul
# Requesting  588 ...... sao felix do xingu
# Requesting  589 ...... deputatskiy
# Requesting  590 ...... awjilah
# Requesting  591 ...... broken hill
# Requesting  592 ...... adelaide
# Requesting  593 ...... pronsk
# Requesting  594 ...... palmer
# Requesting  595 ...... tuy hoa
# Requesting  596 ...... karwar
# Requesting  597 ...... pasni
# Requesting  598 ...... sawtell
# Requesting  599 ...... falakata
# Requesting  600 ...... magadan
# Requesting  601 ...... lasa
# Requesting  602 ...... sukhodol
# Requesting  603 ...... yuzhno-yeniseyskiy .....Error, try again...
# Requesting  604 ...... tambacounda
# Requesting  605 ...... samarai
# Requesting  606 ...... chuguyevka
# Requesting  607 ...... kysyl-syr
# Requesting  608 ...... arrecife
# Requesting  609 ...... matagami
# Requesting  610 ...... nelson bay
# Requesting  611 ...... anton lizardo
# Requesting  612 ...... grants pass
# Requesting  613 ...... waipawa
# Requesting  614 ...... egvekinot
# Requesting  615 ...... mrirt .....Error, try again...
# Requesting  616 ...... borogontsy
# Requesting  617 ...... iralaya
# Requesting  618 ...... mandalgovi
# Requesting  619 ...... rio grande
# Requesting  620 ...... rodos
# Requesting  621 ...... lodja
# Requesting  622 ...... raudeberg
# Requesting  623 ...... ketchikan
# Requesting  624 ...... port hardy
# Requesting  625 ...... rabo de peixe
# Requesting  626 ...... altona
# Requesting  627 ...... grande-riviere .....Error, try again...
# Requesting  628 ...... grindavik
# Requesting  629 ...... havelock
# Requesting  630 ...... hibbing
# Requesting  631 ...... laguna
# Requesting  632 ...... ukiah
# Requesting  633 ...... pyu
# Requesting  634 ...... at-bashi
# Requesting  635 ...... khormuj .....Error, try again...
# Requesting  636 ...... kapit
# Requesting  637 ...... marshall
# Requesting  638 ...... paramonga
# Requesting  639 ...... grasse
# Requesting  640 ...... cedar city
# Requesting  641 ...... aanekoski
# Requesting  642 ...... murwara
# Requesting  643 ...... mitsamiouli
# Requesting  644 ...... mestia

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({
                            " Cities" : cities, 
                            "Cloudiness" : Cloudiness,
                            "Country" : Country, 
                            "Date" : Date,
                            "Humidity" : Humidity, 
                            "Lat" : Lat,
                            "Lng" : Lng,
                            "Max_Temp" : Max_Temp,
                            "Wind_Speed" : Wind_Speed
                        })
cities_df
# Out:
#           Cities Cloudiness Country        Date Humidity    Lat     Lng  \
# 0        vaitupu
# 1         bograd         40      RU  1594945698       93  54.23   90.83
# 2     butaritari         55      KI  1594945465       68   3.07  172.79
# 3          pisco         90      PE  1594945513       82  -13.7  -76.22
# 4    fort nelson         90      CA  1594945699       93  58.81  -122.7
# ..           ...        ...     ...         ...      ...    ...     ...
# 640   cedar city          1      US  1594945802       14  37.68 -113.06
# 641    aanekoski          0      FI  1594945838      100  62.69   25.82
# 642      murwara         19      IN  1594945560       76  23.85    80.4
# 643  mitsamiouli          0      KM  1594945839       73 -11.38   43.28
# 644       mestia          0      GE  1594945839       66  43.05   42.73
#
#     Max_Temp Wind_Speed
# 0
# 1       60.8       6.71
# 2      83.46       9.31
# 3       60.8      11.41
# 4         59       3.36
# ..       ...        ...
# 640     87.8      11.41
# 641       52       3.36
# 642    80.44       4.27
# 643    75.09      25.05
# 644     53.1       2.24
#
# [645 rows x 9 columns]

# %%
cities_df.count()
# Out:
#  Cities       645
# Cloudiness    645
# Country       645
# Date          645
# Humidity      645
# Lat           645
# Lng           645
# Max_Temp      645
# Wind_Speed    645
# dtype: int64

# %%
cities_df.to_csv("cities.csv", encoding="utf-8", index=False)

# %%
cities_df['Date'] = pd.to_datetime(cities_df.Date)

# %%
cities_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0    Cities     645 non-null    object
#  1   Cloudiness  645 non-null    object
#  2   Country     645 non-null    object
#  3   Date        594 non-null    datetime64[ns]
#  4   Humidity    645 non-null    object
#  5   Lat         645 non-null    object
#  6   Lng         645 non-null    object
#  7   Max_Temp    645 non-null    object
#  8   Wind_Speed  645 non-null    object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 45.5+ KB

# %%
cities_df
# Out:
#           Cities Cloudiness Country                          Date Humidity  \
# 0        vaitupu                                              NaT
# 1         bograd         40      RU 1970-01-01 00:00:01.594945698       93
# 2     butaritari         55      KI 1970-01-01 00:00:01.594945465       68
# 3          pisco         90      PE 1970-01-01 00:00:01.594945513       82
# 4    fort nelson         90      CA 1970-01-01 00:00:01.594945699       93
# ..           ...        ...     ...                           ...      ...
# 640   cedar city          1      US 1970-01-01 00:00:01.594945802       14
# 641    aanekoski          0      FI 1970-01-01 00:00:01.594945838      100
# 642      murwara         19      IN 1970-01-01 00:00:01.594945560       76
# 643  mitsamiouli          0      KM 1970-01-01 00:00:01.594945839       73
# 644       mestia          0      GE 1970-01-01 00:00:01.594945839       66
#
#        Lat     Lng Max_Temp Wind_Speed
# 0
# 1    54.23   90.83     60.8       6.71
# 2     3.07  172.79    83.46       9.31
# 3    -13.7  -76.22     60.8      11.41
# 4    58.81  -122.7       59       3.36
# ..     ...     ...      ...        ...
# 640  37.68 -113.06     87.8      11.41
# 641  62.69   25.82       52       3.36
# 642  23.85    80.4    80.44       4.27
# 643 -11.38   43.28    75.09      25.05
# 644  43.05   42.73     53.1       2.24
#
# [645 rows x 9 columns]

# %%
nan_value = float("NaN")
cities_df.replace("", nan_value, inplace = True)
cities_df.dropna(subset = ["Cloudiness"], inplace = True)
cities_df
# Out:
#           Cities  Cloudiness Country                          Date  Humidity  \
# 1         bograd        40.0      RU 1970-01-01 00:00:01.594945698      93.0
# 2     butaritari        55.0      KI 1970-01-01 00:00:01.594945465      68.0
# 3          pisco        90.0      PE 1970-01-01 00:00:01.594945513      82.0
# 4    fort nelson        90.0      CA 1970-01-01 00:00:01.594945699      93.0
# 5         avarua         2.0      CK 1970-01-01 00:00:01.594945699      69.0
# ..           ...         ...     ...                           ...       ...
# 640   cedar city         1.0      US 1970-01-01 00:00:01.594945802      14.0
# 641    aanekoski         0.0      FI 1970-01-01 00:00:01.594945838     100.0
# 642      murwara        19.0      IN 1970-01-01 00:00:01.594945560      76.0
# 643  mitsamiouli         0.0      KM 1970-01-01 00:00:01.594945839      73.0
# 644       mestia         0.0      GE 1970-01-01 00:00:01.594945839      66.0
#
#        Lat     Lng  Max_Temp  Wind_Speed
# 1    54.23   90.83     60.80        6.71
# 2     3.07  172.79     83.46        9.31
# 3   -13.70  -76.22     60.80       11.41
# 4    58.81 -122.70     59.00        3.36
# 5   -21.21 -159.78     73.40       10.29
# ..     ...     ...       ...         ...
# 640  37.68 -113.06     87.80       11.41
# 641  62.69   25.82     52.00        3.36
# 642  23.85   80.40     80.44        4.27
# 643 -11.38   43.28     75.09       25.05
# 644  43.05   42.73     53.10        2.24
#
# [594 rows x 9 columns]

# %%
clean_city_data_df = cities_df
clean_city_data_df
# Out:
#           Cities  Cloudiness Country                          Date  Humidity  \
# 1         bograd        40.0      RU 1970-01-01 00:00:01.594945698      93.0
# 2     butaritari        55.0      KI 1970-01-01 00:00:01.594945465      68.0
# 3          pisco        90.0      PE 1970-01-01 00:00:01.594945513      82.0
# 4    fort nelson        90.0      CA 1970-01-01 00:00:01.594945699      93.0
# 5         avarua         2.0      CK 1970-01-01 00:00:01.594945699      69.0
# ..           ...         ...     ...                           ...       ...
# 640   cedar city         1.0      US 1970-01-01 00:00:01.594945802      14.0
# 641    aanekoski         0.0      FI 1970-01-01 00:00:01.594945838     100.0
# 642      murwara        19.0      IN 1970-01-01 00:00:01.594945560      76.0
# 643  mitsamiouli         0.0      KM 1970-01-01 00:00:01.594945839      73.0
# 644       mestia         0.0      GE 1970-01-01 00:00:01.594945839      66.0
#
#        Lat     Lng  Max_Temp  Wind_Speed
# 1    54.23   90.83     60.80        6.71
# 2     3.07  172.79     83.46        9.31
# 3   -13.70  -76.22     60.80       11.41
# 4    58.81 -122.70     59.00        3.36
# 5   -21.21 -159.78     73.40       10.29
# ..     ...     ...       ...         ...
# 640  37.68 -113.06     87.80       11.41
# 641  62.69   25.82     52.00        3.36
# 642  23.85   80.40     80.44        4.27
# 643 -11.38   43.28     75.09       25.05
# 644  43.05   42.73     53.10        2.24
#
# [594 rows x 9 columns]

# %%
clean_city_data_df.to_csv("clean_cities.csv", encoding="utf-8", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
lat = clean_city_data_df ["Lat"]
temp = clean_city_data_df ["Max_Temp"]

plt.scatter(lat, temp,color="green")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Latitue vs. Max Temperature")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
lat = clean_city_data_df ["Lat"]
hum = clean_city_data_df ["Humidity"]

plt.scatter(lat, hum,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Latitue vs. Humidity")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
lat = clean_city_data_df ["Lat"]
cloud = clean_city_data_df ["Cloudiness"]

plt.scatter(lat, cloud,color="blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Latitue vs. Cloudiness")
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
lat = clean_city_data_df ["Lat"]
wind = clean_city_data_df ["Wind_Speed"]

plt.scatter(lat, wind,color="orange")
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Latitue vs. Wind_Speed")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]>0]
# northern_hemisphere_df
southern_hemisphere_df = clean_city_data_df[clean_city_data_df["Lat"]<0]
# southern_hemisphere_df

# %%
# # OPTIONAL: Create a function to create Linear Regression plots
# x_values = Capomulin_avg["Weight (g)"]
# y_values = Capomulin_avg["Tumor Volume (mm3)"]
# (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# regress_vals = x_values * slope + intercept
# line_eq = "y = " + str(round(slope,4)) + "x + " + str(round(intercept,4))
# plt.scatter(x_values,y_values, color = "green")
# plt.plot(x_values,regress_vals,"r-")
# plt.xlabel("Mouse Weight (grams)")
# plt.ylabel("Average Tumor Volume (mm3)")
# plt.title("Correlation coefficient - Mouse Weight vs Tumor Volume in Capomulin treatment")
# plt.grid()
# plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
n_lat = northern_hemisphere_df ["Lat"]
n_temp = northern_hemisphere_df ["Max_Temp"]
n_lat = northern_hemisphere_df ["Lat"]
plt.scatter(n_lat, n_temp,color="green")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Northern Hemisphere Latitue vs. Max Temperature")
plt.grid()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
s_lat = southern_hemisphere_df ["Lat"]
s_temp = southern_hemisphere_df ["Max_Temp"]

plt.scatter(s_lat, s_temp,color="green")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Farenheit)")
plt.title("Southern Hemisphere Latitue vs. Max Temperature")
plt.grid()
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
n_lat = northern_hemisphere_df ["Lat"]
n_hum = northern_hemisphere_df["Humidity"]

plt.scatter(n_lat, n_hum,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere Latitue vs. Humidity")
plt.grid()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
s_lat = southern_hemisphere_df ["Lat"]
s_hum = southern_hemisphere_df ["Humidity"]

plt.scatter(s_lat,s_hum,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere Latitue vs. Humidity")
plt.grid()
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
n_lat = northern_hemisphere_df ["Lat"]
n_cloud = northern_hemisphere_df ["Cloudiness"]

plt.scatter(n_lat, n_cloud,color="blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere  Latitue vs. Cloudiness")
plt.grid()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
s_lat = southern_hemisphere_df ["Lat"]
s_cloud = southern_hemisphere_df ["Cloudiness"]

plt.scatter(s_lat, s_cloud,color="blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere  Latitue vs. Cloudiness")
plt.grid()
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
n_lat = northern_hemisphere_df ["Lat"]
n_wind = northern_hemisphere_df ["Wind_Speed"]

plt.scatter(n_lat, n_wind,color="orange")
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Northern Hemisphere Latitue vs. Wind_Speed")
plt.grid()
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
s_lat = southern_hemisphere_df ["Lat"]
s_wind = southern_hemisphere_df ["Wind_Speed"]

plt.scatter(s_lat, s_wind,color="orange")
plt.xlabel("Latitude")
plt.ylabel("Wind_Speed")
plt.title("Southern Hemisphere Latitue vs. Wind_Speed")
plt.grid()
plt.show()
